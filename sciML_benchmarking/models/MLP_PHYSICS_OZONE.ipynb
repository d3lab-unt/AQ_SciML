# %%
import pandas as pd
import torch
import torch.nn as nn
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error
import matplotlib.pyplot as plt
import torch.backends.cudnn as cudnn

cudnn.deterministic = True
cudnn.benchmark = False

torch.manual_seed(42)
np.random.seed(42)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")


def get_true_aqi(C):
    breakpoints = [
        ((0.000, 0.054), (0, 50)),
        ((0.05400001, 0.070), (51, 100)),
        ((0.07000001, 0.085), (101, 150)),
        ((0.08500001, 0.105), (151, 200)),
        ((0.10500001, 0.200), (201, 300)),
    ]

    aqi = torch.zeros_like(C)

    for (bp_lo, bp_hi), (i_lo, i_hi) in breakpoints:
        mask = (C >= bp_lo) & (C <= bp_hi)
        aqi[mask] = ((i_hi - i_lo) / (bp_hi - bp_lo)) * (C[mask] - bp_lo) + i_lo

    aqi[C > 500.4] = 500
    return aqi


CSV_PATH = "datasets/final/datasets_lagwise/Ozone_Combined_AQI_2022_2024.csv"
df = pd.read_csv(CSV_PATH)

df["DATE"] = pd.to_datetime(df["Date"], format="%d-%m-%y", dayfirst=True, errors="coerce")
df = df.dropna(subset=["DATE", "Daily_Mean_Ozone", "Daily_AQI_Value"]).reset_index(drop=True)

data = df[["DATE", "Daily_Mean_Ozone", "Daily_AQI_Value"]].copy()
data = data.sort_values("DATE").reset_index(drop=True)

print("\n--- 1. Original Data Frame (Head) ---")
print(data.head())
print("-" * 50)
print("Shape:", data.shape)


class AQIPredictor(nn.Module):
    def __init__(self, n_hidden=64):
        super(AQIPredictor, self).__init__()
        self.net = nn.Sequential(
            nn.Linear(2, n_hidden),
            nn.ReLU(),
            nn.Linear(n_hidden, 32),
            nn.ReLU(),
            nn.Linear(32, 1),
        )

    def forward(self, x):
        return self.net(x)


def data_loss(model, C_scaled, AQI_true):
    AQI_pred = model(C_scaled)
    return torch.mean((AQI_pred - AQI_true) ** 2)


def physics_loss(model, C_unscaled, C_scaled):
    AQI_from_formula = get_true_aqi(C_unscaled).detach()
    AQI_from_model = model(C_scaled)
    return torch.mean((AQI_from_model - AQI_from_formula) ** 2)


results = {
    "LAG": [],
    "Model": [],
    "lambda_data": [],
    "lambda_phys": [],
    "MAE": [],
    "RMSE": [],
    "NMSE": [],
}

lag_list = [1, 7, 14, 30]

lambda_configs = [
    (0.0, 1.0),
    (0.3, 0.7),
    (0.5, 0.5),
    (0.7, 0.3),
    (1.0, 0.0),
]


for LOOKBACK_DAYS in lag_list:
    print(f"\n========================================")
    print(f"Preparing supervised dataset for LAG = {LOOKBACK_DAYS}")
    print(f"========================================")

    tmp = data.copy()
    tmp[f"AQI_Targeted_Value_LAG_{LOOKBACK_DAYS}"] = tmp["Daily_AQI_Value"].shift(-LOOKBACK_DAYS)
    tmp[f"OZONE_Targeted_Value_LAG_{LOOKBACK_DAYS}"] = tmp["Daily_Mean_Ozone"].shift(-LOOKBACK_DAYS)

    supervised_df = (
        tmp[
            [
                "DATE",
                "Daily_Mean_Ozone",
                "Daily_AQI_Value",
                f"AQI_Targeted_Value_LAG_{LOOKBACK_DAYS}",
                f"OZONE_Targeted_Value_LAG_{LOOKBACK_DAYS}",
            ]
        ]
        .dropna()
        .reset_index(drop=True)
    )

    print("\n--- Supervised Data (Head) ---")
    print(supervised_df.head())
    print("-" * 50)
    print("Shape:", supervised_df.shape)

    C_pm25_data = supervised_df["Daily_Mean_Ozone"].values.astype(np.float32).reshape(-1, 1)
    C_aqi_data = supervised_df["Daily_AQI_Value"].values.astype(np.float32).reshape(-1, 1)
    AQI_data = supervised_df[f"AQI_Targeted_Value_LAG_{LOOKBACK_DAYS}"].values.astype(np.float32).reshape(-1, 1)
    PM_Targeted_Value = supervised_df[f"OZONE_Targeted_Value_LAG_{LOOKBACK_DAYS}"].values.astype(np.float32).reshape(-1, 1)

    X_data = np.hstack((C_pm25_data, C_aqi_data))
    y_data = AQI_data
    tar_pm = PM_Targeted_Value

    C_train, C_test, AQI_train, AQI_test, tr_pm, te_pm = train_test_split(
        X_data, y_data, tar_pm, test_size=0.2, random_state=42, shuffle=False
    )

    scaler = StandardScaler()
    C_train_scaled = scaler.fit_transform(C_train)
    C_test_scaled = scaler.transform(C_test)

    C_train_tensor_base = torch.tensor(C_train_scaled, dtype=torch.float32).to(device)
    AQI_train_tensor_base = torch.tensor(AQI_train, dtype=torch.float32).to(device)
    C_test_tensor_base = torch.tensor(C_test_scaled, dtype=torch.float32).to(device)
    AQI_test_tensor_base = torch.tensor(AQI_test, dtype=torch.float32).to(device)

    tr_pm_tensor_base = torch.tensor(tr_pm, dtype=torch.float32).to(device)
    te_pm_tensor_base = torch.tensor(te_pm, dtype=torch.float32).to(device)

    for lambda_data, lambda_phys in lambda_configs:
        torch.manual_seed(42)
        np.random.seed(42)
        print(
            f"\n>>> Training MLP+Physics | LAG = {LOOKBACK_DAYS}, "
            f"lambda_data = {lambda_data}, lambda_phys = {lambda_phys}"
        )

        model = AQIPredictor(n_hidden=64).to(device)
        optimizer = torch.optim.Adam(model.parameters(), lr=0.001)

        num_epochs = 3000
        print_every = 200

        with torch.no_grad():
            aqi_phys_train = get_true_aqi(tr_pm_tensor_base)
            abs_diff = torch.abs(aqi_phys_train - AQI_train_tensor_base)

            print("\n--- First 10 Samples: True vs Physics AQI (Targeted Day) ---")
            for i in range(min(10, len(AQI_train_tensor_base))):
                true_val = float(AQI_train_tensor_base[i].cpu().item())
                phys_val = float(aqi_phys_train[i].cpu().item())
                diff_val = float(abs_diff[i].cpu().item())
                print(f"Sample {i+1:02d}: True={true_val:.3f}, Physics={phys_val:.3f}, Diff={diff_val:.3f}")

        for epoch in range(num_epochs):
            model.train()
            optimizer.zero_grad()

            l_data = data_loss(model, C_train_tensor_base, AQI_train_tensor_base)
            l_phys = physics_loss(model, tr_pm_tensor_base, C_train_tensor_base)

            loss = lambda_data * l_data + lambda_phys * l_phys

            loss.backward()
            optimizer.step()

            if epoch < 5:
                print(
                    f"Epoch {epoch+1}: "
                    f"Data Loss = {l_data.item():.6f}, "
                    f"Physics Loss = {l_phys.item():.6f}, "
                    f"Total Loss = {loss.item():.6f}"
                )

            if (epoch + 1) % print_every == 0:
                print(
                    f"Epoch {epoch+1}/{num_epochs}, "
                    f"Total Loss = {loss.item():.6f}, "
                    f"Data Loss = {l_data.item():.6f}, "
                    f"Physics Loss = {l_phys.item():.6f}"
                )

        model.eval()
        with torch.no_grad():
            AQI_pred_test = model(C_test_tensor_base)

            y_true = AQI_test_tensor_base.cpu().numpy()
            y_pred = AQI_pred_test.cpu().numpy()

            mse = mean_squared_error(y_true, y_pred)
            mae = mean_absolute_error(y_true, y_pred)
            rmse = np.sqrt(mse)

            denom = np.mean((y_true - np.mean(y_true)) ** 2)
            eps = 1e-12
            nmse = mse / (denom + eps)

            print(
                f"\n--- Evaluation | LAG = {LOOKBACK_DAYS}, "
                f"lambda_data = {lambda_data}, lambda_phys = {lambda_phys} ---"
            )
            print(f"Mean Squared Error (MSE):   {mse:.4f}")
            print(f"Mean Absolute Error (MAE):  {mae:.4f}")
            print(f"Root Mean Squared Error (RMSE): {rmse:.4f}")
            print(f"Normalized Mean Squared Error (NMSE): {nmse:.4f}")

        results["LAG"].append(LOOKBACK_DAYS)
        results["Model"].append("MLP+Physics")
        results["lambda_data"].append(lambda_data)
        results["lambda_phys"].append(lambda_phys)
        results["MAE"].append(mae)
        results["RMSE"].append(rmse)
        results["NMSE"].append(nmse)


results_df = pd.DataFrame(results)
results_df.to_csv("OZONE_MLP_Physics_LambdaSweep_Results.csv", index=False)

print("\n===== Final Ozone MLP+Physics Lambda Sweep Results =====")
print(results_df)
# Out:
# Using device: cpu
#
# --- 1. Original Data Frame (Head) ---
#         DATE  Daily_Mean_Ozone  Daily_AQI_Value
# 0 2022-01-01          0.025000        23.000000
# 1 2022-01-02          0.032333        30.333333
# 2 2022-01-03          0.029667        27.666667
# 3 2022-01-04          0.036000        33.333333
# 4 2022-01-05          0.033000        30.666667
# --------------------------------------------------
# Shape: (1091, 3)
#
# ========================================
# Preparing supervised dataset for LAG = 1
# ========================================
#
# --- Supervised Data (Head) ---
#         DATE  Daily_Mean_Ozone  Daily_AQI_Value  AQI_Targeted_Value_LAG_1  \
# 0 2022-01-01          0.025000        23.000000                 30.333333
# 1 2022-01-02          0.032333        30.333333                 27.666667
# 2 2022-01-03          0.029667        27.666667                 33.333333
# 3 2022-01-04          0.036000        33.333333                 30.666667
# 4 2022-01-05          0.033000        30.666667                 23.000000
#
#    OZONE_Targeted_Value_LAG_1
# 0                    0.032333
# 1                    0.029667
# 2                    0.036000
# 3                    0.033000
# 4                    0.025000
# --------------------------------------------------
# Shape: (1090, 5)
#
# >>> Training MLP+Physics | LAG = 1, lambda_data = 0.0, lambda_phys = 1.0
#
# --- First 10 Samples: True vs Physics AQI (Targeted Day) ---
# Sample 01: True=30.333, Physics=29.938, Diff=0.395
# Sample 02: True=27.667, Physics=27.469, Diff=0.198
# Sample 03: True=33.333, Physics=33.333, Diff=0.000
# Sample 04: True=30.667, Physics=30.556, Diff=0.111
# Sample 05: True=23.000, Physics=23.148, Diff=0.148
# Sample 06: True=23.333, Physics=23.457, Diff=0.123
# Sample 07: True=15.667, Physics=15.432, Diff=0.235
# Sample 08: True=24.333, Physics=24.383, Diff=0.049
# Sample 09: True=22.000, Physics=21.914, Diff=0.086
# Sample 10: True=26.667, Physics=26.852, Diff=0.185
# Epoch 1: Data Loss = 2046.311646, Physics Loss = 2071.446777, Total Loss = 2071.446777
# Epoch 2: Data Loss = 2043.560547, Physics Loss = 2068.681885, Total Loss = 2068.681885
# Epoch 3: Data Loss = 2040.886475, Physics Loss = 2065.993896, Total Loss = 2065.993896
# Epoch 4: Data Loss = 2038.278076, Physics Loss = 2063.371826, Total Loss = 2063.371826
# Epoch 5: Data Loss = 2035.703369, Physics Loss = 2060.783447, Total Loss = 2060.783447
# Epoch 200/3000, Total Loss = 404.382538, Data Loss = 395.879791, Physics Loss = 404.382538
# Epoch 400/3000, Total Loss = 212.716248, Data Loss = 206.165955, Physics Loss = 212.716248
# Epoch 600/3000, Total Loss = 203.863724, Data Loss = 196.838089, Physics Loss = 203.863724
# Epoch 800/3000, Total Loss = 202.955475, Data Loss = 195.870605, Physics Loss = 202.955475
# Epoch 1000/3000, Total Loss = 202.633820, Data Loss = 195.551712, Physics Loss = 202.633820
# Epoch 1200/3000, Total Loss = 202.448929, Data Loss = 195.370132, Physics Loss = 202.448929
# Epoch 1400/3000, Total Loss = 202.325653, Data Loss = 195.247650, Physics Loss = 202.325653
# Epoch 1600/3000, Total Loss = 202.232285, Data Loss = 195.155609, Physics Loss = 202.232285
# Epoch 1800/3000, Total Loss = 202.144440, Data Loss = 195.071121, Physics Loss = 202.144440
# Epoch 2000/3000, Total Loss = 202.071854, Data Loss = 194.996613, Physics Loss = 202.071854
# Epoch 2200/3000, Total Loss = 202.015015, Data Loss = 194.938492, Physics Loss = 202.015015
# Epoch 2400/3000, Total Loss = 201.964859, Data Loss = 194.888794, Physics Loss = 201.964859
# Epoch 2600/3000, Total Loss = 201.920013, Data Loss = 194.844879, Physics Loss = 201.920013
# Epoch 2800/3000, Total Loss = 201.875305, Data Loss = 194.800446, Physics Loss = 201.875305
# Epoch 3000/3000, Total Loss = 201.829147, Data Loss = 194.754807, Physics Loss = 201.829147
#
# --- Evaluation | LAG = 1, lambda_data = 0.0, lambda_phys = 1.0 ---
# Mean Squared Error (MSE):   411.5957
# Mean Absolute Error (MAE):  12.9227
# Root Mean Squared Error (RMSE): 20.2878
# Normalized Mean Squared Error (NMSE): 0.6452
#
# >>> Training MLP+Physics | LAG = 1, lambda_data = 0.3, lambda_phys = 0.7
#
# --- First 10 Samples: True vs Physics AQI (Targeted Day) ---
# Sample 01: True=30.333, Physics=29.938, Diff=0.395
# Sample 02: True=27.667, Physics=27.469, Diff=0.198
# Sample 03: True=33.333, Physics=33.333, Diff=0.000
# Sample 04: True=30.667, Physics=30.556, Diff=0.111
# Sample 05: True=23.000, Physics=23.148, Diff=0.148
# Sample 06: True=23.333, Physics=23.457, Diff=0.123
# Sample 07: True=15.667, Physics=15.432, Diff=0.235
# Sample 08: True=24.333, Physics=24.383, Diff=0.049
# Sample 09: True=22.000, Physics=21.914, Diff=0.086
# Sample 10: True=26.667, Physics=26.852, Diff=0.185
# Epoch 1: Data Loss = 2046.311646, Physics Loss = 2071.446777, Total Loss = 2063.906250
# Epoch 2: Data Loss = 2043.560547, Physics Loss = 2068.681885, Total Loss = 2061.145508
# Epoch 3: Data Loss = 2040.886230, Physics Loss = 2065.993896, Total Loss = 2058.461426
# Epoch 4: Data Loss = 2038.278076, Physics Loss = 2063.372070, Total Loss = 2055.843994
# Epoch 5: Data Loss = 2035.703369, Physics Loss = 2060.783447, Total Loss = 2053.259277
# Epoch 200/3000, Total Loss = 402.390686, Data Loss = 396.419983, Physics Loss = 404.949585
# Epoch 400/3000, Total Loss = 210.520386, Data Loss = 205.889374, Physics Loss = 212.505112
# Epoch 600/3000, Total Loss = 201.714310, Data Loss = 196.749496, Physics Loss = 203.842087
# Epoch 800/3000, Total Loss = 200.814056, Data Loss = 195.806702, Physics Loss = 202.960052
# Epoch 1000/3000, Total Loss = 200.498444, Data Loss = 195.492737, Physics Loss = 202.643738
# Epoch 1200/3000, Total Loss = 200.315308, Data Loss = 195.312149, Physics Loss = 202.459534
# Epoch 1400/3000, Total Loss = 200.190399, Data Loss = 195.186920, Physics Loss = 202.334747
# Epoch 1600/3000, Total Loss = 200.094421, Data Loss = 195.091904, Physics Loss = 202.238358
# Epoch 1800/3000, Total Loss = 200.010162, Data Loss = 195.010513, Physics Loss = 202.152863
# Epoch 2000/3000, Total Loss = 199.937668, Data Loss = 194.936310, Physics Loss = 202.081100
# Epoch 2200/3000, Total Loss = 199.882217, Data Loss = 194.880264, Physics Loss = 202.025909
# Epoch 2400/3000, Total Loss = 199.832245, Data Loss = 194.830200, Physics Loss = 201.975967
# Epoch 2600/3000, Total Loss = 199.787628, Data Loss = 194.786148, Physics Loss = 201.931107
# Epoch 2800/3000, Total Loss = 199.742416, Data Loss = 194.740982, Physics Loss = 201.885880
# Epoch 3000/3000, Total Loss = 199.696548, Data Loss = 194.695526, Physics Loss = 201.839844
#
# --- Evaluation | LAG = 1, lambda_data = 0.3, lambda_phys = 0.7 ---
# Mean Squared Error (MSE):   411.5312
# Mean Absolute Error (MAE):  12.9086
# Root Mean Squared Error (RMSE): 20.2862
# Normalized Mean Squared Error (NMSE): 0.6451
#
# >>> Training MLP+Physics | LAG = 1, lambda_data = 0.5, lambda_phys = 0.5
#
# --- First 10 Samples: True vs Physics AQI (Targeted Day) ---
# Sample 01: True=30.333, Physics=29.938, Diff=0.395
# Sample 02: True=27.667, Physics=27.469, Diff=0.198
# Sample 03: True=33.333, Physics=33.333, Diff=0.000
# Sample 04: True=30.667, Physics=30.556, Diff=0.111
# Sample 05: True=23.000, Physics=23.148, Diff=0.148
# Sample 06: True=23.333, Physics=23.457, Diff=0.123
# Sample 07: True=15.667, Physics=15.432, Diff=0.235
# Sample 08: True=24.333, Physics=24.383, Diff=0.049
# Sample 09: True=22.000, Physics=21.914, Diff=0.086
# Sample 10: True=26.667, Physics=26.852, Diff=0.185
# Epoch 1: Data Loss = 2046.311646, Physics Loss = 2071.446777, Total Loss = 2058.879150
# Epoch 2: Data Loss = 2043.560547, Physics Loss = 2068.681885, Total Loss = 2056.121094
# Epoch 3: Data Loss = 2040.886230, Physics Loss = 2065.993896, Total Loss = 2053.439941
# Epoch 4: Data Loss = 2038.278076, Physics Loss = 2063.372070, Total Loss = 2050.825195
# Epoch 5: Data Loss = 2035.703369, Physics Loss = 2060.783203, Total Loss = 2048.243164
# Epoch 200/3000, Total Loss = 401.036469, Data Loss = 396.762726, Physics Loss = 405.310211
# Epoch 400/3000, Total Loss = 209.044464, Data Loss = 205.714767, Physics Loss = 212.374161
# Epoch 600/3000, Total Loss = 200.270142, Data Loss = 196.701584, Physics Loss = 203.838699
# Epoch 800/3000, Total Loss = 199.370865, Data Loss = 195.770447, Physics Loss = 202.971283
# Epoch 1000/3000, Total Loss = 199.062225, Data Loss = 195.463959, Physics Loss = 202.660507
# Epoch 1200/3000, Total Loss = 198.880737, Data Loss = 195.284027, Physics Loss = 202.477448
# Epoch 1400/3000, Total Loss = 198.755051, Data Loss = 195.158005, Physics Loss = 202.352097
# Epoch 1600/3000, Total Loss = 198.658127, Data Loss = 195.062073, Physics Loss = 202.254181
# Epoch 1800/3000, Total Loss = 198.574097, Data Loss = 194.979614, Physics Loss = 202.168579
# Epoch 2000/3000, Total Loss = 198.502914, Data Loss = 194.907242, Physics Loss = 202.098587
# Epoch 2200/3000, Total Loss = 198.448395, Data Loss = 194.852203, Physics Loss = 202.044571
# Epoch 2400/3000, Total Loss = 198.398239, Data Loss = 194.802261, Physics Loss = 201.994217
# Epoch 2600/3000, Total Loss = 198.352905, Data Loss = 194.757294, Physics Loss = 201.948532
# Epoch 2800/3000, Total Loss = 198.309601, Data Loss = 194.713699, Physics Loss = 201.905487
# Epoch 3000/3000, Total Loss = 198.262604, Data Loss = 194.666977, Physics Loss = 201.858231
#
# --- Evaluation | LAG = 1, lambda_data = 0.5, lambda_phys = 0.5 ---
# Mean Squared Error (MSE):   411.5031
# Mean Absolute Error (MAE):  12.9000
# Root Mean Squared Error (RMSE): 20.2855
# Normalized Mean Squared Error (NMSE): 0.6451
#
# >>> Training MLP+Physics | LAG = 1, lambda_data = 0.7, lambda_phys = 0.3
#
# --- First 10 Samples: True vs Physics AQI (Targeted Day) ---
# Sample 01: True=30.333, Physics=29.938, Diff=0.395
# Sample 02: True=27.667, Physics=27.469, Diff=0.198
# Sample 03: True=33.333, Physics=33.333, Diff=0.000
# Sample 04: True=30.667, Physics=30.556, Diff=0.111
# Sample 05: True=23.000, Physics=23.148, Diff=0.148
# Sample 06: True=23.333, Physics=23.457, Diff=0.123
# Sample 07: True=15.667, Physics=15.432, Diff=0.235
# Sample 08: True=24.333, Physics=24.383, Diff=0.049
# Sample 09: True=22.000, Physics=21.914, Diff=0.086
# Sample 10: True=26.667, Physics=26.852, Diff=0.185
# Epoch 1: Data Loss = 2046.311646, Physics Loss = 2071.446777, Total Loss = 2053.852051
# Epoch 2: Data Loss = 2043.560547, Physics Loss = 2068.681885, Total Loss = 2051.096924
# Epoch 3: Data Loss = 2040.886230, Physics Loss = 2065.993896, Total Loss = 2048.418457
# Epoch 4: Data Loss = 2038.277954, Physics Loss = 2063.372070, Total Loss = 2045.806152
# Epoch 5: Data Loss = 2035.703369, Physics Loss = 2060.783203, Total Loss = 2043.227295
# Epoch 200/3000, Total Loss = 399.557678, Data Loss = 396.988159, Physics Loss = 405.553223
# Epoch 400/3000, Total Loss = 207.567291, Data Loss = 205.556030, Physics Loss = 212.260208
# Epoch 600/3000, Total Loss = 198.827988, Data Loss = 196.673096, Physics Loss = 203.856094
# Epoch 800/3000, Total Loss = 197.922104, Data Loss = 195.748291, Physics Loss = 202.994324
# Epoch 1000/3000, Total Loss = 197.619843, Data Loss = 195.447708, Physics Loss = 202.688126
# Epoch 1200/3000, Total Loss = 197.436920, Data Loss = 195.264999, Physics Loss = 202.504700
# Epoch 1400/3000, Total Loss = 197.310471, Data Loss = 195.138870, Physics Loss = 202.377502
# Epoch 1600/3000, Total Loss = 197.212555, Data Loss = 195.041000, Physics Loss = 202.279495
# Epoch 1800/3000, Total Loss = 197.127930, Data Loss = 194.957214, Physics Loss = 202.192917
# Epoch 2000/3000, Total Loss = 197.058746, Data Loss = 194.887512, Physics Loss = 202.124969
# Epoch 2200/3000, Total Loss = 197.004562, Data Loss = 194.832962, Physics Loss = 202.071609
# Epoch 2400/3000, Total Loss = 196.954086, Data Loss = 194.782578, Physics Loss = 202.020935
# Epoch 2600/3000, Total Loss = 196.908264, Data Loss = 194.736877, Physics Loss = 201.974808
# Epoch 2800/3000, Total Loss = 196.864685, Data Loss = 194.693146, Physics Loss = 201.931580
# Epoch 3000/3000, Total Loss = 196.820419, Data Loss = 194.648956, Physics Loss = 201.887131
#
# --- Evaluation | LAG = 1, lambda_data = 0.7, lambda_phys = 0.3 ---
# Mean Squared Error (MSE):   411.4970
# Mean Absolute Error (MAE):  12.8913
# Root Mean Squared Error (RMSE): 20.2854
# Normalized Mean Squared Error (NMSE): 0.6451
#
# >>> Training MLP+Physics | LAG = 1, lambda_data = 1.0, lambda_phys = 0.0
#
# --- First 10 Samples: True vs Physics AQI (Targeted Day) ---
# Sample 01: True=30.333, Physics=29.938, Diff=0.395
# Sample 02: True=27.667, Physics=27.469, Diff=0.198
# Sample 03: True=33.333, Physics=33.333, Diff=0.000
# Sample 04: True=30.667, Physics=30.556, Diff=0.111
# Sample 05: True=23.000, Physics=23.148, Diff=0.148
# Sample 06: True=23.333, Physics=23.457, Diff=0.123
# Sample 07: True=15.667, Physics=15.432, Diff=0.235
# Sample 08: True=24.333, Physics=24.383, Diff=0.049
# Sample 09: True=22.000, Physics=21.914, Diff=0.086
# Sample 10: True=26.667, Physics=26.852, Diff=0.185
# Epoch 1: Data Loss = 2046.311646, Physics Loss = 2071.446777, Total Loss = 2046.311646
# Epoch 2: Data Loss = 2043.560547, Physics Loss = 2068.681885, Total Loss = 2043.560547
# Epoch 3: Data Loss = 2040.886230, Physics Loss = 2065.993652, Total Loss = 2040.886230
# Epoch 4: Data Loss = 2038.277954, Physics Loss = 2063.372070, Total Loss = 2038.277954
# Epoch 5: Data Loss = 2035.703369, Physics Loss = 2060.783203, Total Loss = 2035.703369
# Epoch 200/3000, Total Loss = 397.424011, Data Loss = 397.424011, Physics Loss = 406.015961
# Epoch 400/3000, Total Loss = 205.327072, Data Loss = 205.327072, Physics Loss = 212.097656
# Epoch 600/3000, Total Loss = 196.628433, Data Loss = 196.628433, Physics Loss = 203.879639
# Epoch 800/3000, Total Loss = 195.729050, Data Loss = 195.729050, Physics Loss = 203.039261
# Epoch 1000/3000, Total Loss = 195.434097, Data Loss = 195.434097, Physics Loss = 202.742355
# Epoch 1200/3000, Total Loss = 195.252350, Data Loss = 195.252350, Physics Loss = 202.560974
# Epoch 1400/3000, Total Loss = 195.124802, Data Loss = 195.124802, Physics Loss = 202.432693
# Epoch 1600/3000, Total Loss = 195.028641, Data Loss = 195.028641, Physics Loss = 202.336411
# Epoch 1800/3000, Total Loss = 194.944382, Data Loss = 194.944382, Physics Loss = 202.249359
# Epoch 2000/3000, Total Loss = 194.877121, Data Loss = 194.877121, Physics Loss = 202.183472
# Epoch 2200/3000, Total Loss = 194.823700, Data Loss = 194.823700, Physics Loss = 202.132751
# Epoch 2400/3000, Total Loss = 194.772827, Data Loss = 194.772827, Physics Loss = 202.080597
# Epoch 2600/3000, Total Loss = 194.727142, Data Loss = 194.727142, Physics Loss = 202.034653
# Epoch 2800/3000, Total Loss = 194.683487, Data Loss = 194.683487, Physics Loss = 201.990753
# Epoch 3000/3000, Total Loss = 194.639832, Data Loss = 194.639832, Physics Loss = 201.947922
#
# --- Evaluation | LAG = 1, lambda_data = 1.0, lambda_phys = 0.0 ---
# Mean Squared Error (MSE):   411.5231
# Mean Absolute Error (MAE):  12.8785
# Root Mean Squared Error (RMSE): 20.2860
# Normalized Mean Squared Error (NMSE): 0.6451
#
# ========================================
# Preparing supervised dataset for LAG = 7
# ========================================
#
# --- Supervised Data (Head) ---
#         DATE  Daily_Mean_Ozone  Daily_AQI_Value  AQI_Targeted_Value_LAG_7  \
# 0 2022-01-01          0.025000        23.000000                 15.666667
# 1 2022-01-02          0.032333        30.333333                 24.333333
# 2 2022-01-03          0.029667        27.666667                 22.000000
# 3 2022-01-04          0.036000        33.333333                 26.666667
# 4 2022-01-05          0.033000        30.666667                 29.666667
#
#    OZONE_Targeted_Value_LAG_7
# 0                    0.016667
# 1                    0.026333
# 2                    0.023667
# 3                    0.029000
# 4                    0.032000
# --------------------------------------------------
# Shape: (1084, 5)
#
# >>> Training MLP+Physics | LAG = 7, lambda_data = 0.0, lambda_phys = 1.0
#
# --- First 10 Samples: True vs Physics AQI (Targeted Day) ---
# Sample 01: True=15.667, Physics=15.432, Diff=0.235
# Sample 02: True=24.333, Physics=24.383, Diff=0.049
# Sample 03: True=22.000, Physics=21.914, Diff=0.086
# Sample 04: True=26.667, Physics=26.852, Diff=0.185
# Sample 05: True=29.667, Physics=29.630, Diff=0.037
# Sample 06: True=28.667, Physics=28.704, Diff=0.037
# Sample 07: True=41.333, Physics=41.049, Diff=0.284
# Sample 08: True=26.667, Physics=26.543, Diff=0.123
# Sample 09: True=29.000, Physics=29.012, Diff=0.012
# Sample 10: True=28.667, Physics=28.704, Diff=0.037
# Epoch 1: Data Loss = 2054.170898, Physics Loss = 2079.432373, Total Loss = 2079.432373
# Epoch 2: Data Loss = 2051.471191, Physics Loss = 2076.723633, Total Loss = 2076.723633
# Epoch 3: Data Loss = 2048.852539, Physics Loss = 2074.095215, Total Loss = 2074.095215
# Epoch 4: Data Loss = 2046.302002, Physics Loss = 2071.535889, Total Loss = 2071.535889
# Epoch 5: Data Loss = 2043.794922, Physics Loss = 2069.019775, Total Loss = 2069.019775
# Epoch 200/3000, Total Loss = 525.362915, Data Loss = 510.208984, Physics Loss = 525.362915
# Epoch 400/3000, Total Loss = 311.351868, Data Loss = 298.886200, Physics Loss = 311.351868
# Epoch 600/3000, Total Loss = 295.765350, Data Loss = 283.563629, Physics Loss = 295.765350
# Epoch 800/3000, Total Loss = 295.013824, Data Loss = 282.871765, Physics Loss = 295.013824
# Epoch 1000/3000, Total Loss = 294.775024, Data Loss = 282.661560, Physics Loss = 294.775024
# Epoch 1200/3000, Total Loss = 294.542114, Data Loss = 282.437134, Physics Loss = 294.542114
# Epoch 1400/3000, Total Loss = 294.374725, Data Loss = 282.292297, Physics Loss = 294.374725
# Epoch 1600/3000, Total Loss = 294.260925, Data Loss = 282.190887, Physics Loss = 294.260925
# Epoch 1800/3000, Total Loss = 294.144775, Data Loss = 282.083466, Physics Loss = 294.144775
# Epoch 2000/3000, Total Loss = 294.019623, Data Loss = 281.964447, Physics Loss = 294.019623
# Epoch 2200/3000, Total Loss = 293.847687, Data Loss = 281.797302, Physics Loss = 293.847687
# Epoch 2400/3000, Total Loss = 293.655151, Data Loss = 281.611267, Physics Loss = 293.655151
# Epoch 2600/3000, Total Loss = 293.397675, Data Loss = 281.360168, Physics Loss = 293.397675
# Epoch 2800/3000, Total Loss = 293.107544, Data Loss = 281.076630, Physics Loss = 293.107544
# Epoch 3000/3000, Total Loss = 292.817841, Data Loss = 280.799744, Physics Loss = 292.817841
#
# --- Evaluation | LAG = 7, lambda_data = 0.0, lambda_phys = 1.0 ---
# Mean Squared Error (MSE):   698.8712
# Mean Absolute Error (MAE):  17.5359
# Root Mean Squared Error (RMSE): 26.4362
# Normalized Mean Squared Error (NMSE): 1.0905
#
# >>> Training MLP+Physics | LAG = 7, lambda_data = 0.3, lambda_phys = 0.7
#
# --- First 10 Samples: True vs Physics AQI (Targeted Day) ---
# Sample 01: True=15.667, Physics=15.432, Diff=0.235
# Sample 02: True=24.333, Physics=24.383, Diff=0.049
# Sample 03: True=22.000, Physics=21.914, Diff=0.086
# Sample 04: True=26.667, Physics=26.852, Diff=0.185
# Sample 05: True=29.667, Physics=29.630, Diff=0.037
# Sample 06: True=28.667, Physics=28.704, Diff=0.037
# Sample 07: True=41.333, Physics=41.049, Diff=0.284
# Sample 08: True=26.667, Physics=26.543, Diff=0.123
# Sample 09: True=29.000, Physics=29.012, Diff=0.012
# Sample 10: True=28.667, Physics=28.704, Diff=0.037
# Epoch 1: Data Loss = 2054.170898, Physics Loss = 2079.432373, Total Loss = 2071.854004
# Epoch 2: Data Loss = 2051.471191, Physics Loss = 2076.723633, Total Loss = 2069.147949
# Epoch 3: Data Loss = 2048.852539, Physics Loss = 2074.095215, Total Loss = 2066.522461
# Epoch 4: Data Loss = 2046.302002, Physics Loss = 2071.535889, Total Loss = 2063.965820
# Epoch 5: Data Loss = 2043.794922, Physics Loss = 2069.019775, Total Loss = 2061.452393
# Epoch 200/3000, Total Loss = 521.039429, Data Loss = 510.425232, Physics Loss = 525.588379
# Epoch 400/3000, Total Loss = 307.661621, Data Loss = 298.922699, Physics Loss = 311.406891
# Epoch 600/3000, Total Loss = 292.114960, Data Loss = 283.559784, Physics Loss = 295.781464
# Epoch 800/3000, Total Loss = 291.378052, Data Loss = 282.864288, Physics Loss = 295.026825
# Epoch 1000/3000, Total Loss = 291.134003, Data Loss = 282.639679, Physics Loss = 294.774445
# Epoch 1200/3000, Total Loss = 290.910950, Data Loss = 282.423035, Physics Loss = 294.548615
# Epoch 1400/3000, Total Loss = 290.753937, Data Loss = 282.280212, Physics Loss = 294.385529
# Epoch 1600/3000, Total Loss = 290.640442, Data Loss = 282.175598, Physics Loss = 294.268219
# Epoch 1800/3000, Total Loss = 290.524506, Data Loss = 282.065887, Physics Loss = 294.149628
# Epoch 2000/3000, Total Loss = 290.398926, Data Loss = 281.944702, Physics Loss = 294.022156
# Epoch 2200/3000, Total Loss = 290.234222, Data Loss = 281.782959, Physics Loss = 293.856201
# Epoch 2400/3000, Total Loss = 290.046906, Data Loss = 281.600159, Physics Loss = 293.666962
# Epoch 2600/3000, Total Loss = 289.790527, Data Loss = 281.348083, Physics Loss = 293.408722
# Epoch 2800/3000, Total Loss = 289.506500, Data Loss = 281.069000, Physics Loss = 293.122589
# Epoch 3000/3000, Total Loss = 289.225098, Data Loss = 280.795563, Physics Loss = 292.837738
#
# --- Evaluation | LAG = 7, lambda_data = 0.3, lambda_phys = 0.7 ---
# Mean Squared Error (MSE):   698.4038
# Mean Absolute Error (MAE):  17.5197
# Root Mean Squared Error (RMSE): 26.4273
# Normalized Mean Squared Error (NMSE): 1.0898
#
# >>> Training MLP+Physics | LAG = 7, lambda_data = 0.5, lambda_phys = 0.5
#
# --- First 10 Samples: True vs Physics AQI (Targeted Day) ---
# Sample 01: True=15.667, Physics=15.432, Diff=0.235
# Sample 02: True=24.333, Physics=24.383, Diff=0.049
# Sample 03: True=22.000, Physics=21.914, Diff=0.086
# Sample 04: True=26.667, Physics=26.852, Diff=0.185
# Sample 05: True=29.667, Physics=29.630, Diff=0.037
# Sample 06: True=28.667, Physics=28.704, Diff=0.037
# Sample 07: True=41.333, Physics=41.049, Diff=0.284
# Sample 08: True=26.667, Physics=26.543, Diff=0.123
# Sample 09: True=29.000, Physics=29.012, Diff=0.012
# Sample 10: True=28.667, Physics=28.704, Diff=0.037
# Epoch 1: Data Loss = 2054.170898, Physics Loss = 2079.432373, Total Loss = 2066.801758
# Epoch 2: Data Loss = 2051.471191, Physics Loss = 2076.723633, Total Loss = 2064.097412
# Epoch 3: Data Loss = 2048.852539, Physics Loss = 2074.095215, Total Loss = 2061.473877
# Epoch 4: Data Loss = 2046.302246, Physics Loss = 2071.535645, Total Loss = 2058.918945
# Epoch 5: Data Loss = 2043.794922, Physics Loss = 2069.019775, Total Loss = 2056.407227
# Epoch 200/3000, Total Loss = 518.161255, Data Loss = 510.576599, Physics Loss = 525.745972
# Epoch 400/3000, Total Loss = 305.194580, Data Loss = 298.946289, Physics Loss = 311.442841
# Epoch 600/3000, Total Loss = 289.679077, Data Loss = 283.561462, Physics Loss = 295.796722
# Epoch 800/3000, Total Loss = 288.950012, Data Loss = 282.861816, Physics Loss = 295.038208
# Epoch 1000/3000, Total Loss = 288.707092, Data Loss = 282.632202, Physics Loss = 294.781982
# Epoch 1200/3000, Total Loss = 288.488495, Data Loss = 282.419250, Physics Loss = 294.557739
# Epoch 1400/3000, Total Loss = 288.336426, Data Loss = 282.276642, Physics Loss = 294.396240
# Epoch 1600/3000, Total Loss = 288.224731, Data Loss = 282.171082, Physics Loss = 294.278381
# Epoch 1800/3000, Total Loss = 288.110413, Data Loss = 282.060913, Physics Loss = 294.159943
# Epoch 2000/3000, Total Loss = 287.989136, Data Loss = 281.943237, Physics Loss = 294.035004
# Epoch 2200/3000, Total Loss = 287.824585, Data Loss = 281.780579, Physics Loss = 293.868591
# Epoch 2400/3000, Total Loss = 287.637604, Data Loss = 281.596588, Physics Loss = 293.678619
# Epoch 2600/3000, Total Loss = 287.383148, Data Loss = 281.345184, Physics Loss = 293.421112
# Epoch 2800/3000, Total Loss = 287.098633, Data Loss = 281.063782, Physics Loss = 293.133453
# Epoch 3000/3000, Total Loss = 286.822083, Data Loss = 280.791718, Physics Loss = 292.852448
#
# --- Evaluation | LAG = 7, lambda_data = 0.5, lambda_phys = 0.5 ---
# Mean Squared Error (MSE):   698.2175
# Mean Absolute Error (MAE):  17.5082
# Root Mean Squared Error (RMSE): 26.4238
# Normalized Mean Squared Error (NMSE): 1.0895
#
# >>> Training MLP+Physics | LAG = 7, lambda_data = 0.7, lambda_phys = 0.3
#
# --- First 10 Samples: True vs Physics AQI (Targeted Day) ---
# Sample 01: True=15.667, Physics=15.432, Diff=0.235
# Sample 02: True=24.333, Physics=24.383, Diff=0.049
# Sample 03: True=22.000, Physics=21.914, Diff=0.086
# Sample 04: True=26.667, Physics=26.852, Diff=0.185
# Sample 05: True=29.667, Physics=29.630, Diff=0.037
# Sample 06: True=28.667, Physics=28.704, Diff=0.037
# Sample 07: True=41.333, Physics=41.049, Diff=0.284
# Sample 08: True=26.667, Physics=26.543, Diff=0.123
# Sample 09: True=29.000, Physics=29.012, Diff=0.012
# Sample 10: True=28.667, Physics=28.704, Diff=0.037
# Epoch 1: Data Loss = 2054.170898, Physics Loss = 2079.432373, Total Loss = 2061.749268
# Epoch 2: Data Loss = 2051.471191, Physics Loss = 2076.723633, Total Loss = 2059.046875
# Epoch 3: Data Loss = 2048.852539, Physics Loss = 2074.095459, Total Loss = 2056.425293
# Epoch 4: Data Loss = 2046.302002, Physics Loss = 2071.535645, Total Loss = 2053.872070
# Epoch 5: Data Loss = 2043.794922, Physics Loss = 2069.019775, Total Loss = 2051.362305
# Epoch 200/3000, Total Loss = 515.278931, Data Loss = 510.726257, Physics Loss = 525.901855
# Epoch 400/3000, Total Loss = 302.729492, Data Loss = 298.976807, Physics Loss = 311.485718
# Epoch 600/3000, Total Loss = 287.238678, Data Loss = 283.563873, Physics Loss = 295.813263
# Epoch 800/3000, Total Loss = 286.519592, Data Loss = 282.862640, Physics Loss = 295.052490
# Epoch 1000/3000, Total Loss = 286.278442, Data Loss = 282.629120, Physics Loss = 294.793488
# Epoch 1200/3000, Total Loss = 286.063812, Data Loss = 282.418152, Physics Loss = 294.570343
# Epoch 1400/3000, Total Loss = 285.915131, Data Loss = 282.274933, Physics Loss = 294.408936
# Epoch 1600/3000, Total Loss = 285.805725, Data Loss = 282.168976, Physics Loss = 294.291443
# Epoch 1800/3000, Total Loss = 285.693512, Data Loss = 282.059540, Physics Loss = 294.172729
# Epoch 2000/3000, Total Loss = 285.573303, Data Loss = 281.941284, Physics Loss = 294.047943
# Epoch 2200/3000, Total Loss = 285.411530, Data Loss = 281.780670, Physics Loss = 293.883545
# Epoch 2400/3000, Total Loss = 285.224945, Data Loss = 281.595795, Physics Loss = 293.692993
# Epoch 2600/3000, Total Loss = 284.971497, Data Loss = 281.343933, Physics Loss = 293.435852
# Epoch 2800/3000, Total Loss = 284.688599, Data Loss = 281.063507, Physics Loss = 293.147156
# Epoch 3000/3000, Total Loss = 284.415588, Data Loss = 280.792664, Physics Loss = 292.869080
#
# --- Evaluation | LAG = 7, lambda_data = 0.7, lambda_phys = 0.3 ---
# Mean Squared Error (MSE):   697.6935
# Mean Absolute Error (MAE):  17.4972
# Root Mean Squared Error (RMSE): 26.4139
# Normalized Mean Squared Error (NMSE): 1.0887
#
# >>> Training MLP+Physics | LAG = 7, lambda_data = 1.0, lambda_phys = 0.0
#
# --- First 10 Samples: True vs Physics AQI (Targeted Day) ---
# Sample 01: True=15.667, Physics=15.432, Diff=0.235
# Sample 02: True=24.333, Physics=24.383, Diff=0.049
# Sample 03: True=22.000, Physics=21.914, Diff=0.086
# Sample 04: True=26.667, Physics=26.852, Diff=0.185
# Sample 05: True=29.667, Physics=29.630, Diff=0.037
# Sample 06: True=28.667, Physics=28.704, Diff=0.037
# Sample 07: True=41.333, Physics=41.049, Diff=0.284
# Sample 08: True=26.667, Physics=26.543, Diff=0.123
# Sample 09: True=29.000, Physics=29.012, Diff=0.012
# Sample 10: True=28.667, Physics=28.704, Diff=0.037
# Epoch 1: Data Loss = 2054.170898, Physics Loss = 2079.432373, Total Loss = 2054.170898
# Epoch 2: Data Loss = 2051.471191, Physics Loss = 2076.723633, Total Loss = 2051.471191
# Epoch 3: Data Loss = 2048.852539, Physics Loss = 2074.095459, Total Loss = 2048.852539
# Epoch 4: Data Loss = 2046.302246, Physics Loss = 2071.535889, Total Loss = 2046.302246
# Epoch 5: Data Loss = 2043.794922, Physics Loss = 2069.019775, Total Loss = 2043.794922
# Epoch 200/3000, Total Loss = 510.948029, Data Loss = 510.948029, Physics Loss = 526.132874
# Epoch 400/3000, Total Loss = 298.991119, Data Loss = 298.991119, Physics Loss = 311.518860
# Epoch 600/3000, Total Loss = 283.576050, Data Loss = 283.576050, Physics Loss = 295.845184
# Epoch 800/3000, Total Loss = 282.867950, Data Loss = 282.867950, Physics Loss = 295.078033
# Epoch 1000/3000, Total Loss = 282.627808, Data Loss = 282.627808, Physics Loss = 294.816437
# Epoch 1200/3000, Total Loss = 282.423004, Data Loss = 282.423004, Physics Loss = 294.596405
# Epoch 1400/3000, Total Loss = 282.278320, Data Loss = 282.278320, Physics Loss = 294.434357
# Epoch 1600/3000, Total Loss = 282.171539, Data Loss = 282.171539, Physics Loss = 294.316223
# Epoch 1800/3000, Total Loss = 282.061768, Data Loss = 282.061768, Physics Loss = 294.197327
# Epoch 2000/3000, Total Loss = 281.943939, Data Loss = 281.943939, Physics Loss = 294.073120
# Epoch 2200/3000, Total Loss = 281.776489, Data Loss = 281.776489, Physics Loss = 293.903717
# Epoch 2400/3000, Total Loss = 281.585938, Data Loss = 281.585938, Physics Loss = 293.707703
# Epoch 2600/3000, Total Loss = 281.337585, Data Loss = 281.337585, Physics Loss = 293.454102
# Epoch 2800/3000, Total Loss = 281.057983, Data Loss = 281.057983, Physics Loss = 293.167358
# Epoch 3000/3000, Total Loss = 280.786102, Data Loss = 280.786102, Physics Loss = 292.886902
#
# --- Evaluation | LAG = 7, lambda_data = 1.0, lambda_phys = 0.0 ---
# Mean Squared Error (MSE):   697.0792
# Mean Absolute Error (MAE):  17.4830
# Root Mean Squared Error (RMSE): 26.4023
# Normalized Mean Squared Error (NMSE): 1.0877
#
# ========================================
# Preparing supervised dataset for LAG = 14
# ========================================
#
# --- Supervised Data (Head) ---
#         DATE  Daily_Mean_Ozone  Daily_AQI_Value  AQI_Targeted_Value_LAG_14  \
# 0 2022-01-01          0.025000        23.000000                  26.666667
# 1 2022-01-02          0.032333        30.333333                  29.000000
# 2 2022-01-03          0.029667        27.666667                  28.666667
# 3 2022-01-04          0.036000        33.333333                  40.666667
# 4 2022-01-05          0.033000        30.666667                  23.333333
#
#    OZONE_Targeted_Value_LAG_14
# 0                     0.028667
# 1                     0.031333
# 2                     0.031000
# 3                     0.044000
# 4                     0.025333
# --------------------------------------------------
# Shape: (1077, 5)
#
# >>> Training MLP+Physics | LAG = 14, lambda_data = 0.0, lambda_phys = 1.0
#
# --- First 10 Samples: True vs Physics AQI (Targeted Day) ---
# Sample 01: True=26.667, Physics=26.543, Diff=0.123
# Sample 02: True=29.000, Physics=29.012, Diff=0.012
# Sample 03: True=28.667, Physics=28.704, Diff=0.037
# Sample 04: True=40.667, Physics=40.741, Diff=0.074
# Sample 05: True=23.333, Physics=23.457, Diff=0.123
# Sample 06: True=26.000, Physics=25.926, Diff=0.074
# Sample 07: True=26.500, Physics=26.389, Diff=0.111
# Sample 08: True=25.000, Physics=25.000, Diff=0.000
# Sample 09: True=33.500, Physics=33.333, Diff=0.167
# Sample 10: True=18.000, Physics=18.056, Diff=0.056
# Epoch 1: Data Loss = 2064.470215, Physics Loss = 2089.953613, Total Loss = 2089.953613
# Epoch 2: Data Loss = 2061.800049, Physics Loss = 2087.274170, Total Loss = 2087.274170
# Epoch 3: Data Loss = 2059.209961, Physics Loss = 2084.674316, Total Loss = 2084.674316
# Epoch 4: Data Loss = 2056.686768, Physics Loss = 2082.141357, Total Loss = 2082.141357
# Epoch 5: Data Loss = 2054.206543, Physics Loss = 2079.651855, Total Loss = 2079.651855
# Epoch 200/3000, Total Loss = 575.863037, Data Loss = 560.372437, Physics Loss = 575.863037
# Epoch 400/3000, Total Loss = 339.494476, Data Loss = 326.139130, Physics Loss = 339.494476
# Epoch 600/3000, Total Loss = 323.276031, Data Loss = 309.967926, Physics Loss = 323.276031
# Epoch 800/3000, Total Loss = 322.266113, Data Loss = 308.960449, Physics Loss = 322.266113
# Epoch 1000/3000, Total Loss = 321.796631, Data Loss = 308.494843, Physics Loss = 321.796631
# Epoch 1200/3000, Total Loss = 321.532837, Data Loss = 308.230835, Physics Loss = 321.532837
# Epoch 1400/3000, Total Loss = 321.349854, Data Loss = 308.050201, Physics Loss = 321.349854
# Epoch 1600/3000, Total Loss = 321.221771, Data Loss = 307.922119, Physics Loss = 321.221771
# Epoch 1800/3000, Total Loss = 321.115814, Data Loss = 307.816132, Physics Loss = 321.115814
# Epoch 2000/3000, Total Loss = 321.026825, Data Loss = 307.726196, Physics Loss = 321.026825
# Epoch 2200/3000, Total Loss = 320.944733, Data Loss = 307.644623, Physics Loss = 320.944733
# Epoch 2400/3000, Total Loss = 320.860291, Data Loss = 307.558655, Physics Loss = 320.860291
# Epoch 2600/3000, Total Loss = 320.780060, Data Loss = 307.478119, Physics Loss = 320.780060
# Epoch 2800/3000, Total Loss = 320.699219, Data Loss = 307.396698, Physics Loss = 320.699219
# Epoch 3000/3000, Total Loss = 320.613617, Data Loss = 307.310394, Physics Loss = 320.613617
#
# --- Evaluation | LAG = 14, lambda_data = 0.0, lambda_phys = 1.0 ---
# Mean Squared Error (MSE):   569.9834
# Mean Absolute Error (MAE):  16.0406
# Root Mean Squared Error (RMSE): 23.8743
# Normalized Mean Squared Error (NMSE): 0.8853
#
# >>> Training MLP+Physics | LAG = 14, lambda_data = 0.3, lambda_phys = 0.7
#
# --- First 10 Samples: True vs Physics AQI (Targeted Day) ---
# Sample 01: True=26.667, Physics=26.543, Diff=0.123
# Sample 02: True=29.000, Physics=29.012, Diff=0.012
# Sample 03: True=28.667, Physics=28.704, Diff=0.037
# Sample 04: True=40.667, Physics=40.741, Diff=0.074
# Sample 05: True=23.333, Physics=23.457, Diff=0.123
# Sample 06: True=26.000, Physics=25.926, Diff=0.074
# Sample 07: True=26.500, Physics=26.389, Diff=0.111
# Sample 08: True=25.000, Physics=25.000, Diff=0.000
# Sample 09: True=33.500, Physics=33.333, Diff=0.167
# Sample 10: True=18.000, Physics=18.056, Diff=0.056
# Epoch 1: Data Loss = 2064.470215, Physics Loss = 2089.953613, Total Loss = 2082.308594
# Epoch 2: Data Loss = 2061.800049, Physics Loss = 2087.274170, Total Loss = 2079.631836
# Epoch 3: Data Loss = 2059.209961, Physics Loss = 2084.674316, Total Loss = 2077.034912
# Epoch 4: Data Loss = 2056.686768, Physics Loss = 2082.141357, Total Loss = 2074.504883
# Epoch 5: Data Loss = 2054.206543, Physics Loss = 2079.651855, Total Loss = 2072.018066
# Epoch 200/3000, Total Loss = 571.358215, Data Loss = 560.508850, Physics Loss = 576.007935
# Epoch 400/3000, Total Loss = 335.443695, Data Loss = 326.084015, Physics Loss = 339.454987
# Epoch 600/3000, Total Loss = 319.281494, Data Loss = 309.954773, Physics Loss = 323.278687
# Epoch 800/3000, Total Loss = 318.272522, Data Loss = 308.947479, Physics Loss = 322.268951
# Epoch 1000/3000, Total Loss = 317.803833, Data Loss = 308.480682, Physics Loss = 321.799500
# Epoch 1200/3000, Total Loss = 317.539368, Data Loss = 308.217346, Physics Loss = 321.534485
# Epoch 1400/3000, Total Loss = 317.356628, Data Loss = 308.035522, Physics Loss = 321.351379
# Epoch 1600/3000, Total Loss = 317.227112, Data Loss = 307.906036, Physics Loss = 321.221863
# Epoch 1800/3000, Total Loss = 317.124878, Data Loss = 307.803802, Physics Loss = 321.119629
# Epoch 2000/3000, Total Loss = 317.034790, Data Loss = 307.712921, Physics Loss = 321.029877
# Epoch 2200/3000, Total Loss = 316.950989, Data Loss = 307.628448, Physics Loss = 320.946381
# Epoch 2400/3000, Total Loss = 316.866577, Data Loss = 307.543701, Physics Loss = 320.862091
# Epoch 2600/3000, Total Loss = 316.786621, Data Loss = 307.463135, Physics Loss = 320.782410
# Epoch 2800/3000, Total Loss = 316.706818, Data Loss = 307.382782, Physics Loss = 320.702820
# Epoch 3000/3000, Total Loss = 316.621033, Data Loss = 307.296997, Physics Loss = 320.617065
#
# --- Evaluation | LAG = 14, lambda_data = 0.3, lambda_phys = 0.7 ---
# Mean Squared Error (MSE):   570.2161
# Mean Absolute Error (MAE):  16.0338
# Root Mean Squared Error (RMSE): 23.8792
# Normalized Mean Squared Error (NMSE): 0.8857
#
# >>> Training MLP+Physics | LAG = 14, lambda_data = 0.5, lambda_phys = 0.5
#
# --- First 10 Samples: True vs Physics AQI (Targeted Day) ---
# Sample 01: True=26.667, Physics=26.543, Diff=0.123
# Sample 02: True=29.000, Physics=29.012, Diff=0.012
# Sample 03: True=28.667, Physics=28.704, Diff=0.037
# Sample 04: True=40.667, Physics=40.741, Diff=0.074
# Sample 05: True=23.333, Physics=23.457, Diff=0.123
# Sample 06: True=26.000, Physics=25.926, Diff=0.074
# Sample 07: True=26.500, Physics=26.389, Diff=0.111
# Sample 08: True=25.000, Physics=25.000, Diff=0.000
# Sample 09: True=33.500, Physics=33.333, Diff=0.167
# Sample 10: True=18.000, Physics=18.056, Diff=0.056
# Epoch 1: Data Loss = 2064.470215, Physics Loss = 2089.953613, Total Loss = 2077.211914
# Epoch 2: Data Loss = 2061.800049, Physics Loss = 2087.274170, Total Loss = 2074.537109
# Epoch 3: Data Loss = 2059.209961, Physics Loss = 2084.674316, Total Loss = 2071.942139
# Epoch 4: Data Loss = 2056.686768, Physics Loss = 2082.141357, Total Loss = 2069.414062
# Epoch 5: Data Loss = 2054.206543, Physics Loss = 2079.651855, Total Loss = 2066.929199
# Epoch 200/3000, Total Loss = 568.355774, Data Loss = 560.603271, Physics Loss = 576.108276
# Epoch 400/3000, Total Loss = 332.739807, Data Loss = 326.049133, Physics Loss = 339.430450
# Epoch 600/3000, Total Loss = 316.615295, Data Loss = 309.948090, Physics Loss = 323.282532
# Epoch 800/3000, Total Loss = 315.607422, Data Loss = 308.941559, Physics Loss = 322.273254
# Epoch 1000/3000, Total Loss = 315.137085, Data Loss = 308.472778, Physics Loss = 321.801361
# Epoch 1200/3000, Total Loss = 314.874146, Data Loss = 308.210266, Physics Loss = 321.537994
# Epoch 1400/3000, Total Loss = 314.694763, Data Loss = 308.031433, Physics Loss = 321.358063
# Epoch 1600/3000, Total Loss = 314.561066, Data Loss = 307.897827, Physics Loss = 321.224304
# Epoch 1800/3000, Total Loss = 314.458740, Data Loss = 307.794861, Physics Loss = 321.122620
# Epoch 2000/3000, Total Loss = 314.369049, Data Loss = 307.705688, Physics Loss = 321.032410
# Epoch 2200/3000, Total Loss = 314.284088, Data Loss = 307.619751, Physics Loss = 320.948425
# Epoch 2400/3000, Total Loss = 314.198181, Data Loss = 307.533325, Physics Loss = 320.863068
# Epoch 2600/3000, Total Loss = 314.119568, Data Loss = 307.454712, Physics Loss = 320.784454
# Epoch 2800/3000, Total Loss = 314.039307, Data Loss = 307.373993, Physics Loss = 320.704620
# Epoch 3000/3000, Total Loss = 313.953918, Data Loss = 307.288727, Physics Loss = 320.619080
#
# --- Evaluation | LAG = 14, lambda_data = 0.5, lambda_phys = 0.5 ---
# Mean Squared Error (MSE):   570.2928
# Mean Absolute Error (MAE):  16.0278
# Root Mean Squared Error (RMSE): 23.8808
# Normalized Mean Squared Error (NMSE): 0.8858
#
# >>> Training MLP+Physics | LAG = 14, lambda_data = 0.7, lambda_phys = 0.3
#
# --- First 10 Samples: True vs Physics AQI (Targeted Day) ---
# Sample 01: True=26.667, Physics=26.543, Diff=0.123
# Sample 02: True=29.000, Physics=29.012, Diff=0.012
# Sample 03: True=28.667, Physics=28.704, Diff=0.037
# Sample 04: True=40.667, Physics=40.741, Diff=0.074
# Sample 05: True=23.333, Physics=23.457, Diff=0.123
# Sample 06: True=26.000, Physics=25.926, Diff=0.074
# Sample 07: True=26.500, Physics=26.389, Diff=0.111
# Sample 08: True=25.000, Physics=25.000, Diff=0.000
# Sample 09: True=33.500, Physics=33.333, Diff=0.167
# Sample 10: True=18.000, Physics=18.056, Diff=0.056
# Epoch 1: Data Loss = 2064.470215, Physics Loss = 2089.953613, Total Loss = 2072.115234
# Epoch 2: Data Loss = 2061.800049, Physics Loss = 2087.274170, Total Loss = 2069.442383
# Epoch 3: Data Loss = 2059.209961, Physics Loss = 2084.674316, Total Loss = 2066.849121
# Epoch 4: Data Loss = 2056.686768, Physics Loss = 2082.141357, Total Loss = 2064.323242
# Epoch 5: Data Loss = 2054.206543, Physics Loss = 2079.651855, Total Loss = 2061.840088
# Epoch 200/3000, Total Loss = 565.351990, Data Loss = 560.698669, Physics Loss = 576.209717
# Epoch 400/3000, Total Loss = 330.038574, Data Loss = 326.021088, Physics Loss = 339.412750
# Epoch 600/3000, Total Loss = 313.947906, Data Loss = 309.944397, Physics Loss = 323.289429
# Epoch 800/3000, Total Loss = 312.940308, Data Loss = 308.937714, Physics Loss = 322.279663
# Epoch 1000/3000, Total Loss = 312.469269, Data Loss = 308.467438, Physics Loss = 321.806915
# Epoch 1200/3000, Total Loss = 312.206360, Data Loss = 308.204681, Physics Loss = 321.543640
# Epoch 1400/3000, Total Loss = 312.028259, Data Loss = 308.026917, Physics Loss = 321.364777
# Epoch 1600/3000, Total Loss = 311.893158, Data Loss = 307.891876, Physics Loss = 321.229523
# Epoch 1800/3000, Total Loss = 311.790070, Data Loss = 307.788544, Physics Loss = 321.126984
# Epoch 2000/3000, Total Loss = 311.699371, Data Loss = 307.697815, Physics Loss = 321.036346
# Epoch 2200/3000, Total Loss = 311.613525, Data Loss = 307.611908, Physics Loss = 320.950592
# Epoch 2400/3000, Total Loss = 311.528381, Data Loss = 307.526459, Physics Loss = 320.866150
# Epoch 2600/3000, Total Loss = 311.450256, Data Loss = 307.447906, Physics Loss = 320.789062
# Epoch 2800/3000, Total Loss = 311.370026, Data Loss = 307.367371, Physics Loss = 320.709595
# Epoch 3000/3000, Total Loss = 311.284943, Data Loss = 307.282654, Physics Loss = 320.623596
#
# --- Evaluation | LAG = 14, lambda_data = 0.7, lambda_phys = 0.3 ---
# Mean Squared Error (MSE):   570.3661
# Mean Absolute Error (MAE):  16.0212
# Root Mean Squared Error (RMSE): 23.8823
# Normalized Mean Squared Error (NMSE): 0.8859
#
# >>> Training MLP+Physics | LAG = 14, lambda_data = 1.0, lambda_phys = 0.0
#
# --- First 10 Samples: True vs Physics AQI (Targeted Day) ---
# Sample 01: True=26.667, Physics=26.543, Diff=0.123
# Sample 02: True=29.000, Physics=29.012, Diff=0.012
# Sample 03: True=28.667, Physics=28.704, Diff=0.037
# Sample 04: True=40.667, Physics=40.741, Diff=0.074
# Sample 05: True=23.333, Physics=23.457, Diff=0.123
# Sample 06: True=26.000, Physics=25.926, Diff=0.074
# Sample 07: True=26.500, Physics=26.389, Diff=0.111
# Sample 08: True=25.000, Physics=25.000, Diff=0.000
# Sample 09: True=33.500, Physics=33.333, Diff=0.167
# Sample 10: True=18.000, Physics=18.056, Diff=0.056
# Epoch 1: Data Loss = 2064.470215, Physics Loss = 2089.953613, Total Loss = 2064.470215
# Epoch 2: Data Loss = 2061.800049, Physics Loss = 2087.274170, Total Loss = 2061.800049
# Epoch 3: Data Loss = 2059.209961, Physics Loss = 2084.674316, Total Loss = 2059.209961
# Epoch 4: Data Loss = 2056.686768, Physics Loss = 2082.141357, Total Loss = 2056.686768
# Epoch 5: Data Loss = 2054.206543, Physics Loss = 2079.651855, Total Loss = 2054.206543
# Epoch 200/3000, Total Loss = 560.841003, Data Loss = 560.841003, Physics Loss = 576.360718
# Epoch 400/3000, Total Loss = 326.012634, Data Loss = 326.012634, Physics Loss = 339.419800
# Epoch 600/3000, Total Loss = 309.945129, Data Loss = 309.945129, Physics Loss = 323.305908
# Epoch 800/3000, Total Loss = 308.940704, Data Loss = 308.940704, Physics Loss = 322.302185
# Epoch 1000/3000, Total Loss = 308.465088, Data Loss = 308.465088, Physics Loss = 321.820190
# Epoch 1200/3000, Total Loss = 308.201477, Data Loss = 308.201477, Physics Loss = 321.556122
# Epoch 1400/3000, Total Loss = 308.023651, Data Loss = 308.023651, Physics Loss = 321.377655
# Epoch 1600/3000, Total Loss = 307.890900, Data Loss = 307.890900, Physics Loss = 321.245361
# Epoch 1800/3000, Total Loss = 307.787354, Data Loss = 307.787354, Physics Loss = 321.141907
# Epoch 2000/3000, Total Loss = 307.696777, Data Loss = 307.696777, Physics Loss = 321.053284
# Epoch 2200/3000, Total Loss = 307.609253, Data Loss = 307.609253, Physics Loss = 320.966095
# Epoch 2400/3000, Total Loss = 307.525360, Data Loss = 307.525360, Physics Loss = 320.882416
# Epoch 2600/3000, Total Loss = 307.447815, Data Loss = 307.447815, Physics Loss = 320.805267
# Epoch 2800/3000, Total Loss = 307.367859, Data Loss = 307.367859, Physics Loss = 320.726593
# Epoch 3000/3000, Total Loss = 307.152252, Data Loss = 307.152252, Physics Loss = 320.512665
#
# --- Evaluation | LAG = 14, lambda_data = 1.0, lambda_phys = 0.0 ---
# Mean Squared Error (MSE):   570.3972
# Mean Absolute Error (MAE):  16.0078
# Root Mean Squared Error (RMSE): 23.8830
# Normalized Mean Squared Error (NMSE): 0.8860
#
# ========================================
# Preparing supervised dataset for LAG = 30
# ========================================
#
# --- Supervised Data (Head) ---
#         DATE  Daily_Mean_Ozone  Daily_AQI_Value  AQI_Targeted_Value_LAG_30  \
# 0 2022-01-01          0.025000        23.000000                  31.333333
# 1 2022-01-02          0.032333        30.333333                  33.000000
# 2 2022-01-03          0.029667        27.666667                  27.666667
# 3 2022-01-04          0.036000        33.333333                  28.666667
# 4 2022-01-05          0.033000        30.666667                  34.000000
#
#    OZONE_Targeted_Value_LAG_30
# 0                     0.034000
# 1                     0.035667
# 2                     0.029667
# 3                     0.031000
# 4                     0.037000
# --------------------------------------------------
# Shape: (1061, 5)
#
# >>> Training MLP+Physics | LAG = 30, lambda_data = 0.0, lambda_phys = 1.0
#
# --- First 10 Samples: True vs Physics AQI (Targeted Day) ---
# Sample 01: True=31.333, Physics=31.481, Diff=0.148
# Sample 02: True=33.000, Physics=33.025, Diff=0.025
# Sample 03: True=27.667, Physics=27.469, Diff=0.198
# Sample 04: True=28.667, Physics=28.704, Diff=0.037
# Sample 05: True=34.000, Physics=34.259, Diff=0.259
# Sample 06: True=34.000, Physics=33.951, Diff=0.049
# Sample 07: True=36.333, Physics=36.420, Diff=0.086
# Sample 08: True=30.333, Physics=30.247, Diff=0.086
# Sample 09: True=34.333, Physics=34.259, Diff=0.074
# Sample 10: True=32.333, Physics=32.407, Diff=0.074
# Epoch 1: Data Loss = 2088.558594, Physics Loss = 2114.246582, Total Loss = 2114.246582
# Epoch 2: Data Loss = 2085.910645, Physics Loss = 2111.590820, Total Loss = 2111.590820
# Epoch 3: Data Loss = 2083.347656, Physics Loss = 2109.020264, Total Loss = 2109.020264
# Epoch 4: Data Loss = 2080.853027, Physics Loss = 2106.518555, Total Loss = 2106.518555
# Epoch 5: Data Loss = 2078.407959, Physics Loss = 2104.066406, Total Loss = 2104.066406
# Epoch 200/3000, Total Loss = 629.847900, Data Loss = 611.939209, Physics Loss = 629.847900
# Epoch 400/3000, Total Loss = 383.380432, Data Loss = 368.172241, Physics Loss = 383.380432
# Epoch 600/3000, Total Loss = 363.275330, Data Loss = 348.480896, Physics Loss = 363.275330
# Epoch 800/3000, Total Loss = 362.495361, Data Loss = 347.713074, Physics Loss = 362.495361
# Epoch 1000/3000, Total Loss = 362.046539, Data Loss = 347.256409, Physics Loss = 362.046539
# Epoch 1200/3000, Total Loss = 361.540710, Data Loss = 346.748901, Physics Loss = 361.540710
# Epoch 1400/3000, Total Loss = 360.930542, Data Loss = 346.142822, Physics Loss = 360.930542
# Epoch 1600/3000, Total Loss = 360.243134, Data Loss = 345.463043, Physics Loss = 360.243134
# Epoch 1800/3000, Total Loss = 359.655548, Data Loss = 344.884399, Physics Loss = 359.655548
# Epoch 2000/3000, Total Loss = 359.043213, Data Loss = 344.275879, Physics Loss = 359.043213
# Epoch 2200/3000, Total Loss = 358.334564, Data Loss = 343.580078, Physics Loss = 358.334564
# Epoch 2400/3000, Total Loss = 357.593689, Data Loss = 342.845398, Physics Loss = 357.593689
# Epoch 2600/3000, Total Loss = 356.861725, Data Loss = 342.123596, Physics Loss = 356.861725
# Epoch 2800/3000, Total Loss = 356.084991, Data Loss = 341.361664, Physics Loss = 356.084991
# Epoch 3000/3000, Total Loss = 355.240265, Data Loss = 340.515137, Physics Loss = 355.240265
#
# --- Evaluation | LAG = 30, lambda_data = 0.0, lambda_phys = 1.0 ---
# Mean Squared Error (MSE):   636.3333
# Mean Absolute Error (MAE):  17.5058
# Root Mean Squared Error (RMSE): 25.2256
# Normalized Mean Squared Error (NMSE): 0.9757
#
# >>> Training MLP+Physics | LAG = 30, lambda_data = 0.3, lambda_phys = 0.7
#
# --- First 10 Samples: True vs Physics AQI (Targeted Day) ---
# Sample 01: True=31.333, Physics=31.481, Diff=0.148
# Sample 02: True=33.000, Physics=33.025, Diff=0.025
# Sample 03: True=27.667, Physics=27.469, Diff=0.198
# Sample 04: True=28.667, Physics=28.704, Diff=0.037
# Sample 05: True=34.000, Physics=34.259, Diff=0.259
# Sample 06: True=34.000, Physics=33.951, Diff=0.049
# Sample 07: True=36.333, Physics=36.420, Diff=0.086
# Sample 08: True=30.333, Physics=30.247, Diff=0.086
# Sample 09: True=34.333, Physics=34.259, Diff=0.074
# Sample 10: True=32.333, Physics=32.407, Diff=0.074
# Epoch 1: Data Loss = 2088.558594, Physics Loss = 2114.246582, Total Loss = 2106.540039
# Epoch 2: Data Loss = 2085.910645, Physics Loss = 2111.590820, Total Loss = 2103.886719
# Epoch 3: Data Loss = 2083.347656, Physics Loss = 2109.020264, Total Loss = 2101.318604
# Epoch 4: Data Loss = 2080.853027, Physics Loss = 2106.518555, Total Loss = 2098.818848
# Epoch 5: Data Loss = 2078.407959, Physics Loss = 2104.066406, Total Loss = 2096.368896
# Epoch 200/3000, Total Loss = 624.602417, Data Loss = 612.063660, Physics Loss = 629.976135
# Epoch 400/3000, Total Loss = 378.861237, Data Loss = 368.208923, Physics Loss = 383.426514
# Epoch 600/3000, Total Loss = 358.842468, Data Loss = 348.478271, Physics Loss = 363.284271
# Epoch 800/3000, Total Loss = 358.059448, Data Loss = 347.703644, Physics Loss = 362.497620
# Epoch 1000/3000, Total Loss = 357.608337, Data Loss = 347.247284, Physics Loss = 362.048798
# Epoch 1200/3000, Total Loss = 357.107269, Data Loss = 346.744537, Physics Loss = 361.548431
# Epoch 1400/3000, Total Loss = 356.502563, Data Loss = 346.141907, Physics Loss = 360.942871
# Epoch 1600/3000, Total Loss = 355.823914, Data Loss = 345.470581, Physics Loss = 360.261047
# Epoch 1800/3000, Total Loss = 355.249817, Data Loss = 344.901031, Physics Loss = 359.684998
# Epoch 2000/3000, Total Loss = 354.684601, Data Loss = 344.338623, Physics Loss = 359.118591
# Epoch 2200/3000, Total Loss = 353.979370, Data Loss = 343.640228, Physics Loss = 358.410461
# Epoch 2400/3000, Total Loss = 353.219635, Data Loss = 342.884277, Physics Loss = 357.649078
# Epoch 2600/3000, Total Loss = 352.467499, Data Loss = 342.136230, Physics Loss = 356.895172
# Epoch 2800/3000, Total Loss = 351.779724, Data Loss = 341.460419, Physics Loss = 356.202271
# Epoch 3000/3000, Total Loss = 350.976807, Data Loss = 340.655945, Physics Loss = 355.400055
#
# --- Evaluation | LAG = 30, lambda_data = 0.3, lambda_phys = 0.7 ---
# Mean Squared Error (MSE):   636.6155
# Mean Absolute Error (MAE):  17.4972
# Root Mean Squared Error (RMSE): 25.2312
# Normalized Mean Squared Error (NMSE): 0.9762
#
# >>> Training MLP+Physics | LAG = 30, lambda_data = 0.5, lambda_phys = 0.5
#
# --- First 10 Samples: True vs Physics AQI (Targeted Day) ---
# Sample 01: True=31.333, Physics=31.481, Diff=0.148
# Sample 02: True=33.000, Physics=33.025, Diff=0.025
# Sample 03: True=27.667, Physics=27.469, Diff=0.198
# Sample 04: True=28.667, Physics=28.704, Diff=0.037
# Sample 05: True=34.000, Physics=34.259, Diff=0.259
# Sample 06: True=34.000, Physics=33.951, Diff=0.049
# Sample 07: True=36.333, Physics=36.420, Diff=0.086
# Sample 08: True=30.333, Physics=30.247, Diff=0.086
# Sample 09: True=34.333, Physics=34.259, Diff=0.074
# Sample 10: True=32.333, Physics=32.407, Diff=0.074
# Epoch 1: Data Loss = 2088.558594, Physics Loss = 2114.246582, Total Loss = 2101.402588
# Epoch 2: Data Loss = 2085.910645, Physics Loss = 2111.590820, Total Loss = 2098.750732
# Epoch 3: Data Loss = 2083.347656, Physics Loss = 2109.020264, Total Loss = 2096.184082
# Epoch 4: Data Loss = 2080.853027, Physics Loss = 2106.518555, Total Loss = 2093.685791
# Epoch 5: Data Loss = 2078.407959, Physics Loss = 2104.066406, Total Loss = 2091.237305
# Epoch 200/3000, Total Loss = 621.104370, Data Loss = 612.146667, Physics Loss = 630.062012
# Epoch 400/3000, Total Loss = 375.847168, Data Loss = 368.235046, Physics Loss = 383.459290
# Epoch 600/3000, Total Loss = 355.879150, Data Loss = 348.471741, Physics Loss = 363.286560
# Epoch 800/3000, Total Loss = 355.089752, Data Loss = 347.688751, Physics Loss = 362.490753
# Epoch 1000/3000, Total Loss = 354.636871, Data Loss = 347.231659, Physics Loss = 362.042084
# Epoch 1200/3000, Total Loss = 354.135864, Data Loss = 346.729889, Physics Loss = 361.541840
# Epoch 1400/3000, Total Loss = 353.535583, Data Loss = 346.131195, Physics Loss = 360.939972
# Epoch 1600/3000, Total Loss = 352.856689, Data Loss = 345.456604, Physics Loss = 360.256775
# Epoch 1800/3000, Total Loss = 352.293884, Data Loss = 344.895844, Physics Loss = 359.691895
# Epoch 2000/3000, Total Loss = 351.738953, Data Loss = 344.344879, Physics Loss = 359.133057
# Epoch 2200/3000, Total Loss = 351.028015, Data Loss = 343.637207, Physics Loss = 358.418854
# Epoch 2400/3000, Total Loss = 350.260559, Data Loss = 342.871338, Physics Loss = 357.649750
# Epoch 2600/3000, Total Loss = 349.504547, Data Loss = 342.121124, Physics Loss = 356.887970
# Epoch 2800/3000, Total Loss = 348.802917, Data Loss = 341.426636, Physics Loss = 356.179199
# Epoch 3000/3000, Total Loss = 348.008118, Data Loss = 340.635986, Physics Loss = 355.380219
#
# --- Evaluation | LAG = 30, lambda_data = 0.5, lambda_phys = 0.5 ---
# Mean Squared Error (MSE):   636.6634
# Mean Absolute Error (MAE):  17.4954
# Root Mean Squared Error (RMSE): 25.2322
# Normalized Mean Squared Error (NMSE): 0.9763
#
# >>> Training MLP+Physics | LAG = 30, lambda_data = 0.7, lambda_phys = 0.3
#
# --- First 10 Samples: True vs Physics AQI (Targeted Day) ---
# Sample 01: True=31.333, Physics=31.481, Diff=0.148
# Sample 02: True=33.000, Physics=33.025, Diff=0.025
# Sample 03: True=27.667, Physics=27.469, Diff=0.198
# Sample 04: True=28.667, Physics=28.704, Diff=0.037
# Sample 05: True=34.000, Physics=34.259, Diff=0.259
# Sample 06: True=34.000, Physics=33.951, Diff=0.049
# Sample 07: True=36.333, Physics=36.420, Diff=0.086
# Sample 08: True=30.333, Physics=30.247, Diff=0.086
# Sample 09: True=34.333, Physics=34.259, Diff=0.074
# Sample 10: True=32.333, Physics=32.407, Diff=0.074
# Epoch 1: Data Loss = 2088.558594, Physics Loss = 2114.246582, Total Loss = 2096.264893
# Epoch 2: Data Loss = 2085.910645, Physics Loss = 2111.590820, Total Loss = 2093.614746
# Epoch 3: Data Loss = 2083.347656, Physics Loss = 2109.020264, Total Loss = 2091.049561
# Epoch 4: Data Loss = 2080.853027, Physics Loss = 2106.518555, Total Loss = 2088.552734
# Epoch 5: Data Loss = 2078.407959, Physics Loss = 2104.066406, Total Loss = 2086.105469
# Epoch 200/3000, Total Loss = 617.604431, Data Loss = 612.229065, Physics Loss = 630.147034
# Epoch 400/3000, Total Loss = 372.831604, Data Loss = 368.262421, Physics Loss = 383.493011
# Epoch 600/3000, Total Loss = 352.922852, Data Loss = 348.476685, Physics Loss = 363.297302
# Epoch 800/3000, Total Loss = 352.131378, Data Loss = 347.688446, Physics Loss = 362.498169
# Epoch 1000/3000, Total Loss = 351.676880, Data Loss = 347.231567, Physics Loss = 362.049347
# Epoch 1200/3000, Total Loss = 351.181000, Data Loss = 346.735016, Physics Loss = 361.554993
# Epoch 1400/3000, Total Loss = 350.585754, Data Loss = 346.140839, Physics Loss = 360.957214
# Epoch 1600/3000, Total Loss = 349.903320, Data Loss = 345.460449, Physics Loss = 360.270050
# Epoch 1800/3000, Total Loss = 349.332214, Data Loss = 344.891541, Physics Loss = 359.693848
# Epoch 2000/3000, Total Loss = 348.779510, Data Loss = 344.341034, Physics Loss = 359.135956
# Epoch 2200/3000, Total Loss = 348.059021, Data Loss = 343.622681, Physics Loss = 358.410522
# Epoch 2400/3000, Total Loss = 347.296875, Data Loss = 342.861572, Physics Loss = 357.645966
# Epoch 2600/3000, Total Loss = 346.543518, Data Loss = 342.112457, Physics Loss = 356.882629
# Epoch 2800/3000, Total Loss = 345.839508, Data Loss = 341.411285, Physics Loss = 356.172028
# Epoch 3000/3000, Total Loss = 345.050964, Data Loss = 340.623779, Physics Loss = 355.381073
#
# --- Evaluation | LAG = 30, lambda_data = 0.7, lambda_phys = 0.3 ---
# Mean Squared Error (MSE):   636.7451
# Mean Absolute Error (MAE):  17.4841
# Root Mean Squared Error (RMSE): 25.2338
# Normalized Mean Squared Error (NMSE): 0.9764
#
# >>> Training MLP+Physics | LAG = 30, lambda_data = 1.0, lambda_phys = 0.0
#
# --- First 10 Samples: True vs Physics AQI (Targeted Day) ---
# Sample 01: True=31.333, Physics=31.481, Diff=0.148
# Sample 02: True=33.000, Physics=33.025, Diff=0.025
# Sample 03: True=27.667, Physics=27.469, Diff=0.198
# Sample 04: True=28.667, Physics=28.704, Diff=0.037
# Sample 05: True=34.000, Physics=34.259, Diff=0.259
# Sample 06: True=34.000, Physics=33.951, Diff=0.049
# Sample 07: True=36.333, Physics=36.420, Diff=0.086
# Sample 08: True=30.333, Physics=30.247, Diff=0.086
# Sample 09: True=34.333, Physics=34.259, Diff=0.074
# Sample 10: True=32.333, Physics=32.407, Diff=0.074
# Epoch 1: Data Loss = 2088.558594, Physics Loss = 2114.246582, Total Loss = 2088.558594
# Epoch 2: Data Loss = 2085.910645, Physics Loss = 2111.590820, Total Loss = 2085.910645
# Epoch 3: Data Loss = 2083.347656, Physics Loss = 2109.020264, Total Loss = 2083.347656
# Epoch 4: Data Loss = 2080.852783, Physics Loss = 2106.518555, Total Loss = 2080.852783
# Epoch 5: Data Loss = 2078.408203, Physics Loss = 2104.066406, Total Loss = 2078.408203
# Epoch 200/3000, Total Loss = 612.355774, Data Loss = 612.355774, Physics Loss = 630.277771
# Epoch 400/3000, Total Loss = 368.305969, Data Loss = 368.305969, Physics Loss = 383.546021
# Epoch 600/3000, Total Loss = 348.483856, Data Loss = 348.483856, Physics Loss = 363.309021
# Epoch 800/3000, Total Loss = 347.686676, Data Loss = 347.686676, Physics Loss = 362.507690
# Epoch 1000/3000, Total Loss = 347.226685, Data Loss = 347.226685, Physics Loss = 362.056458
# Epoch 1200/3000, Total Loss = 346.734161, Data Loss = 346.734161, Physics Loss = 361.565186
# Epoch 1400/3000, Total Loss = 346.140076, Data Loss = 346.140076, Physics Loss = 360.968262
# Epoch 1600/3000, Total Loss = 345.467712, Data Loss = 345.467712, Physics Loss = 360.290588
# Epoch 1800/3000, Total Loss = 344.904968, Data Loss = 344.904968, Physics Loss = 359.719971
# Epoch 2000/3000, Total Loss = 344.376648, Data Loss = 344.376648, Physics Loss = 359.184357
# Epoch 2200/3000, Total Loss = 343.669159, Data Loss = 343.669159, Physics Loss = 358.474487
# Epoch 2400/3000, Total Loss = 342.940094, Data Loss = 342.940094, Physics Loss = 357.738708
# Epoch 2600/3000, Total Loss = 342.213074, Data Loss = 342.213074, Physics Loss = 357.000488
# Epoch 2800/3000, Total Loss = 341.519745, Data Loss = 341.519745, Physics Loss = 356.294708
# Epoch 3000/3000, Total Loss = 340.745941, Data Loss = 340.745941, Physics Loss = 355.521332
#
# --- Evaluation | LAG = 30, lambda_data = 1.0, lambda_phys = 0.0 ---
# Mean Squared Error (MSE):   637.0201
# Mean Absolute Error (MAE):  17.4687
# Root Mean Squared Error (RMSE): 25.2393
# Normalized Mean Squared Error (NMSE): 0.9768
#
# ===== Final Ozone MLP+Physics Lambda Sweep Results =====
#     LAG        Model  lambda_data  lambda_phys        MAE       RMSE      NMSE
# 0     1  MLP+Physics          0.0          1.0  12.922710  20.287822  0.645212
# 1     1  MLP+Physics          0.3          0.7  12.908557  20.286232  0.645111
# 2     1  MLP+Physics          0.5          0.5  12.900032  20.285538  0.645067
# 3     1  MLP+Physics          0.7          0.3  12.891294  20.285388  0.645057
# 4     1  MLP+Physics          1.0          0.0  12.878457  20.286032  0.645098
# 5     7  MLP+Physics          0.0          1.0  17.535854  26.436171  1.090519
# 6     7  MLP+Physics          0.3          0.7  17.519747  26.427331  1.089790
# 7     7  MLP+Physics          0.5          0.5  17.508192  26.423805  1.089499
# 8     7  MLP+Physics          0.7          0.3  17.497223  26.413888  1.088681
# 9     7  MLP+Physics          1.0          0.0  17.483034  26.402258  1.087723
# 10   14  MLP+Physics          0.0          1.0  16.040585  23.874325  0.885316
# 11   14  MLP+Physics          0.3          0.7  16.033838  23.879197  0.885678
# 12   14  MLP+Physics          0.5          0.5  16.027798  23.880804  0.885797
# 13   14  MLP+Physics          0.7          0.3  16.021206  23.882338  0.885911
# 14   14  MLP+Physics          1.0          0.0  16.007835  23.882989  0.885959
# 15   30  MLP+Physics          0.0          1.0  17.505787  25.225648  0.975745
# 16   30  MLP+Physics          0.3          0.7  17.497208  25.231240  0.976178
# 17   30  MLP+Physics          0.5          0.5  17.495443  25.232190  0.976251
# 18   30  MLP+Physics          0.7          0.3  17.484095  25.233808  0.976376
# 19   30  MLP+Physics          1.0          0.0  17.468708  25.239257  0.976798

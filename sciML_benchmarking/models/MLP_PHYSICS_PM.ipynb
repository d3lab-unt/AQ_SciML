# %%
import pandas as pd
import torch
import torch.nn as nn
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error
import matplotlib.pyplot as plt
import torch.backends.cudnn as cudnn

cudnn.deterministic = True
cudnn.benchmark = False

torch.manual_seed(42)
np.random.seed(42)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")


def get_true_aqi(C):
    breakpoints = [
        ((0.0, 9.0), (0, 50)),
        ((9.001, 35.4), (51, 100)),
        ((35.401, 55.4), (101, 150)),
        ((55.401, 125.4), (151, 200)),
        ((125.401, 225.4), (201, 300)),
        ((225.401, 325.4), (301, 400)),
        ((325.401, 500.4), (401, 500)),
    ]

    aqi = torch.zeros_like(C)

    for (bp_lo, bp_hi), (i_lo, i_hi) in breakpoints:
        mask = (C >= bp_lo) & (C <= bp_hi)
        aqi[mask] = ((i_hi - i_lo) / (bp_hi - bp_lo)) * (C[mask] - bp_lo) + i_lo

    aqi[C > 500.4] = 500
    return aqi


CSV_PATH = "datasets/final/datasets_lagwise/PM_Combined_AQI_2022_2024.csv"
df = pd.read_csv(CSV_PATH)

df["DATE"] = pd.to_datetime(df["Date"], format="%d-%m-%y", dayfirst=True, errors="coerce")
df = df.dropna(subset=["DATE", "Daily_Mean_PM", "Daily_AQI_Value"]).reset_index(drop=True)

data = df[["DATE", "Daily_Mean_PM", "Daily_AQI_Value"]].copy()
data = data.sort_values("DATE").reset_index(drop=True)

print("\n--- 1. Original Data Frame (Head) ---")
print(data.head())
print("-" * 50)
print("Shape:", data.shape)


class AQIPredictor(nn.Module):
    def __init__(self, n_hidden=64):
        super(AQIPredictor, self).__init__()
        self.net = nn.Sequential(
            nn.Linear(2, n_hidden),
            nn.ReLU(),
            nn.Linear(n_hidden, 32),
            nn.ReLU(),
            nn.Linear(32, 1),
        )

    def forward(self, x):
        return self.net(x)


def data_loss(model, C_scaled, AQI_true):
    AQI_pred = model(C_scaled)
    return torch.mean((AQI_pred - AQI_true) ** 2)


def physics_loss(model, C_unscaled, C_scaled):
    AQI_from_formula = get_true_aqi(C_unscaled).detach()
    AQI_from_model = model(C_scaled)
    return torch.mean((AQI_from_model - AQI_from_formula) ** 2)


results = {
    "LAG": [],
    "Model": [],
    "lambda_data": [],
    "lambda_phys": [],
    "MAE": [],
    "RMSE": [],
    "NMSE": [],
}

lag_list = [1, 7, 14, 30]

lambda_configs = [
    (0.0, 1.0),
    (0.3, 0.7),
    (0.5, 0.5),
    (0.7, 0.3),
    (1.0, 0.0),
]


for LOOKBACK_DAYS in lag_list:
    print(f"\n========================================")
    print(f"Preparing supervised dataset for LAG = {LOOKBACK_DAYS}")
    print(f"========================================")

    tmp = data.copy()
    tmp[f"AQI_Targeted_Value_LAG_{LOOKBACK_DAYS}"] = tmp["Daily_AQI_Value"].shift(-LOOKBACK_DAYS)
    tmp[f"PM_Targeted_Value_LAG_{LOOKBACK_DAYS}"] = tmp["Daily_Mean_PM"].shift(-LOOKBACK_DAYS)

    supervised_df = (
        tmp[
            [
                "DATE",
                "Daily_Mean_PM",
                "Daily_AQI_Value",
                f"AQI_Targeted_Value_LAG_{LOOKBACK_DAYS}",
                f"PM_Targeted_Value_LAG_{LOOKBACK_DAYS}",
            ]
        ]
        .dropna()
        .reset_index(drop=True)
    )

    print("\n--- Supervised Data (Head) ---")
    print(supervised_df.head())
    print("-" * 50)
    print("Shape:", supervised_df.shape)

    C_pm25_data = supervised_df["Daily_Mean_PM"].values.astype(np.float32).reshape(-1, 1)
    C_aqi_data = supervised_df["Daily_AQI_Value"].values.astype(np.float32).reshape(-1, 1)
    AQI_data = supervised_df[f"AQI_Targeted_Value_LAG_{LOOKBACK_DAYS}"].values.astype(np.float32).reshape(-1, 1)
    PM_Targeted_Value = supervised_df[f"PM_Targeted_Value_LAG_{LOOKBACK_DAYS}"].values.astype(np.float32).reshape(-1, 1)

    X_data = np.hstack((C_pm25_data, C_aqi_data))
    y_data = AQI_data
    tar_pm = PM_Targeted_Value

    C_train, C_test, AQI_train, AQI_test, tr_pm, te_pm = train_test_split(
        X_data, y_data, tar_pm, test_size=0.2, random_state=42, shuffle=False
    )

    scaler = StandardScaler()
    C_train_scaled = scaler.fit_transform(C_train)
    C_test_scaled = scaler.transform(C_test)

    C_train_tensor_base = torch.tensor(C_train_scaled, dtype=torch.float32).to(device)
    AQI_train_tensor_base = torch.tensor(AQI_train, dtype=torch.float32).to(device)
    C_test_tensor_base = torch.tensor(C_test_scaled, dtype=torch.float32).to(device)
    AQI_test_tensor_base = torch.tensor(AQI_test, dtype=torch.float32).to(device)

    tr_pm_tensor_base = torch.tensor(tr_pm, dtype=torch.float32).to(device)
    te_pm_tensor_base = torch.tensor(te_pm, dtype=torch.float32).to(device)

    for lambda_data, lambda_phys in lambda_configs:
        torch.manual_seed(42)
        np.random.seed(42)
        print(
            f"\n>>> Training MLP+Physics | LAG = {LOOKBACK_DAYS}, "
            f"lambda_data = {lambda_data}, lambda_phys = {lambda_phys}"
        )

        model = AQIPredictor(n_hidden=64).to(device)
        optimizer = torch.optim.Adam(model.parameters(), lr=0.001)

        num_epochs = 3000
        print_every = 200

        with torch.no_grad():
            aqi_phys_train = get_true_aqi(tr_pm_tensor_base)
            abs_diff = torch.abs(aqi_phys_train - AQI_train_tensor_base)

            print("\n--- First 10 Samples: True vs Physics AQI (Targeted Day) ---")
            for i in range(min(10, len(AQI_train_tensor_base))):
                true_val = float(AQI_train_tensor_base[i].cpu().item())
                phys_val = float(aqi_phys_train[i].cpu().item())
                diff_val = float(abs_diff[i].cpu().item())
                print(f"Sample {i+1:02d}: True={true_val:.3f}, Physics={phys_val:.3f}, Diff={diff_val:.3f}")

        for epoch in range(num_epochs):
            model.train()
            optimizer.zero_grad()

            l_data = data_loss(model, C_train_tensor_base, AQI_train_tensor_base)
            l_phys = physics_loss(model, tr_pm_tensor_base, C_train_tensor_base)

            loss = lambda_data * l_data + lambda_phys * l_phys

            loss.backward()
            optimizer.step()

            if epoch < 5:
                print(
                    f"Epoch {epoch+1}: "
                    f"Data Loss = {l_data.item():.6f}, "
                    f"Physics Loss = {l_phys.item():.6f}, "
                    f"Total Loss = {loss.item():.6f}"
                )

            if (epoch + 1) % print_every == 0:
                print(
                    f"Epoch {epoch+1}/{num_epochs}, "
                    f"Total Loss = {loss.item():.6f}, "
                    f"Data Loss = {l_data.item():.6f}, "
                    f"Physics Loss = {l_phys.item():.6f}"
                )

        model.eval()
        with torch.no_grad():
            AQI_pred_test = model(C_test_tensor_base)

            y_true = AQI_test_tensor_base.cpu().numpy()
            y_pred = AQI_pred_test.cpu().numpy()

            mse = mean_squared_error(y_true, y_pred)
            mae = mean_absolute_error(y_true, y_pred)
            rmse = np.sqrt(mse)

            denom = np.mean((y_true - np.mean(y_true)) ** 2)
            eps = 1e-12
            nmse = mse / (denom + eps)

            print(
                f"\n--- Evaluation | LAG = {LOOKBACK_DAYS}, "
                f"lambda_data = {lambda_data}, lambda_phys = {lambda_phys} ---"
            )
            print(f"Mean Squared Error (MSE):   {mse:.4f}")
            print(f"Mean Absolute Error (MAE):  {mae:.4f}")
            print(f"Root Mean Squared Error (RMSE): {rmse:.4f}")
            print(f"Normalized Mean Squared Error (NMSE): {nmse:.4f}")

        results["LAG"].append(LOOKBACK_DAYS)
        results["Model"].append("MLP+Physics")
        results["lambda_data"].append(lambda_data)
        results["lambda_phys"].append(lambda_phys)
        results["MAE"].append(mae)
        results["RMSE"].append(rmse)
        results["NMSE"].append(nmse)


results_df = pd.DataFrame(results)
results_df.to_csv("PM25_MLP_Physics_LambdaSweep_Results.csv", index=False)

print("\n===== Final MLP+Physics Lambda Sweep Results =====")
print(results_df)
# Out:
# Using device: cpu
#
# --- 1. Original Data Frame (Head) ---
#         DATE  Daily_Mean_PM  Daily_AQI_Value
# 0 2022-01-01            6.1        34.000000
# 1 2022-01-02            4.6        26.000000
# 2 2022-01-03            9.6        52.000000
# 3 2022-01-04            5.3        29.000000
# 4 2022-01-05            5.9        32.666667
# --------------------------------------------------
# Shape: (1094, 3)
#
# ========================================
# Preparing supervised dataset for LAG = 1
# ========================================
#
# --- Supervised Data (Head) ---
#         DATE  Daily_Mean_PM  Daily_AQI_Value  AQI_Targeted_Value_LAG_1  \
# 0 2022-01-01            6.1        34.000000                 26.000000
# 1 2022-01-02            4.6        26.000000                 52.000000
# 2 2022-01-03            9.6        52.000000                 29.000000
# 3 2022-01-04            5.3        29.000000                 32.666667
# 4 2022-01-05            5.9        32.666667                 39.000000
#
#    PM_Targeted_Value_LAG_1
# 0                      4.6
# 1                      9.6
# 2                      5.3
# 3                      5.9
# 4                      7.1
# --------------------------------------------------
# Shape: (1093, 5)
#
# >>> Training MLP+Physics | LAG = 1, lambda_data = 0.0, lambda_phys = 1.0
#
# --- First 10 Samples: True vs Physics AQI (Targeted Day) ---
# Sample 01: True=26.000, Physics=25.556, Diff=0.444
# Sample 02: True=52.000, Physics=52.112, Diff=0.112
# Sample 03: True=29.000, Physics=29.444, Diff=0.444
# Sample 04: True=32.667, Physics=32.778, Diff=0.111
# Sample 05: True=39.000, Physics=39.444, Diff=0.444
# Sample 06: True=42.000, Physics=41.667, Diff=0.333
# Sample 07: True=61.000, Physics=61.145, Diff=0.145
# Sample 08: True=23.000, Physics=23.333, Diff=0.333
# Sample 09: True=31.000, Physics=31.111, Diff=0.111
# Sample 10: True=49.000, Physics=49.444, Diff=0.444
# Epoch 1: Data Loss = 2325.867920, Physics Loss = 2353.988770, Total Loss = 2353.988770
# Epoch 2: Data Loss = 2322.986572, Physics Loss = 2351.092041, Total Loss = 2351.092041
# Epoch 3: Data Loss = 2320.198730, Physics Loss = 2348.289307, Total Loss = 2348.289307
# Epoch 4: Data Loss = 2317.485352, Physics Loss = 2345.561035, Total Loss = 2345.561035
# Epoch 5: Data Loss = 2314.849854, Physics Loss = 2342.911133, Total Loss = 2342.911133
# Epoch 200/3000, Total Loss = 572.350952, Data Loss = 560.590088, Physics Loss = 572.350952
# Epoch 400/3000, Total Loss = 201.035339, Data Loss = 196.944168, Physics Loss = 201.035339
# Epoch 600/3000, Total Loss = 166.501556, Data Loss = 164.007050, Physics Loss = 166.501556
# Epoch 800/3000, Total Loss = 164.109146, Data Loss = 161.719070, Physics Loss = 164.109146
# Epoch 1000/3000, Total Loss = 163.282211, Data Loss = 160.926880, Physics Loss = 163.282211
# Epoch 1200/3000, Total Loss = 162.815689, Data Loss = 160.478745, Physics Loss = 162.815689
# Epoch 1400/3000, Total Loss = 162.491531, Data Loss = 160.172577, Physics Loss = 162.491531
# Epoch 1600/3000, Total Loss = 162.291367, Data Loss = 159.993973, Physics Loss = 162.291367
# Epoch 1800/3000, Total Loss = 162.139893, Data Loss = 159.864578, Physics Loss = 162.139893
# Epoch 2000/3000, Total Loss = 161.857468, Data Loss = 159.621185, Physics Loss = 161.857468
# Epoch 2200/3000, Total Loss = 161.352737, Data Loss = 159.120209, Physics Loss = 161.352737
# Epoch 2400/3000, Total Loss = 161.022598, Data Loss = 158.808212, Physics Loss = 161.022598
# Epoch 2600/3000, Total Loss = 160.862991, Data Loss = 158.653748, Physics Loss = 160.862991
# Epoch 2800/3000, Total Loss = 160.761444, Data Loss = 158.552811, Physics Loss = 160.761444
# Epoch 3000/3000, Total Loss = 160.687714, Data Loss = 158.478745, Physics Loss = 160.687714
#
# --- Evaluation | LAG = 1, lambda_data = 0.0, lambda_phys = 1.0 ---
# Mean Squared Error (MSE):   113.1015
# Mean Absolute Error (MAE):  8.1695
# Root Mean Squared Error (RMSE): 10.6349
# Normalized Mean Squared Error (NMSE): 0.6560
#
# >>> Training MLP+Physics | LAG = 1, lambda_data = 0.3, lambda_phys = 0.7
#
# --- First 10 Samples: True vs Physics AQI (Targeted Day) ---
# Sample 01: True=26.000, Physics=25.556, Diff=0.444
# Sample 02: True=52.000, Physics=52.112, Diff=0.112
# Sample 03: True=29.000, Physics=29.444, Diff=0.444
# Sample 04: True=32.667, Physics=32.778, Diff=0.111
# Sample 05: True=39.000, Physics=39.444, Diff=0.444
# Sample 06: True=42.000, Physics=41.667, Diff=0.333
# Sample 07: True=61.000, Physics=61.145, Diff=0.145
# Sample 08: True=23.000, Physics=23.333, Diff=0.333
# Sample 09: True=31.000, Physics=31.111, Diff=0.111
# Sample 10: True=49.000, Physics=49.444, Diff=0.444
# Epoch 1: Data Loss = 2325.867920, Physics Loss = 2353.988770, Total Loss = 2345.552490
# Epoch 2: Data Loss = 2322.986572, Physics Loss = 2351.092041, Total Loss = 2342.660400
# Epoch 3: Data Loss = 2320.198730, Physics Loss = 2348.289307, Total Loss = 2339.862061
# Epoch 4: Data Loss = 2317.485352, Physics Loss = 2345.561035, Total Loss = 2337.138184
# Epoch 5: Data Loss = 2314.849854, Physics Loss = 2342.911133, Total Loss = 2334.492676
# Epoch 200/3000, Total Loss = 569.123962, Data Loss = 560.881470, Physics Loss = 572.656433
# Epoch 400/3000, Total Loss = 200.048782, Data Loss = 197.154266, Physics Loss = 201.289276
# Epoch 600/3000, Total Loss = 165.770508, Data Loss = 163.989471, Physics Loss = 166.533813
# Epoch 800/3000, Total Loss = 163.391815, Data Loss = 161.684158, Physics Loss = 164.123672
# Epoch 1000/3000, Total Loss = 162.582977, Data Loss = 160.899384, Physics Loss = 163.304520
# Epoch 1200/3000, Total Loss = 162.118484, Data Loss = 160.447525, Physics Loss = 162.834610
# Epoch 1400/3000, Total Loss = 161.807098, Data Loss = 160.149094, Physics Loss = 162.517685
# Epoch 1600/3000, Total Loss = 161.608307, Data Loss = 159.965332, Physics Loss = 162.312439
# Epoch 1800/3000, Total Loss = 161.463837, Data Loss = 159.835098, Physics Loss = 162.161865
# Epoch 2000/3000, Total Loss = 161.288055, Data Loss = 159.677368, Physics Loss = 161.978348
# Epoch 2200/3000, Total Loss = 160.768829, Data Loss = 159.172333, Physics Loss = 161.453033
# Epoch 2400/3000, Total Loss = 160.390015, Data Loss = 158.802856, Physics Loss = 161.070236
# Epoch 2600/3000, Total Loss = 160.211029, Data Loss = 158.627792, Physics Loss = 160.889572
# Epoch 2800/3000, Total Loss = 160.100952, Data Loss = 158.518616, Physics Loss = 160.779083
# Epoch 3000/3000, Total Loss = 160.023788, Data Loss = 158.441727, Physics Loss = 160.701813
#
# --- Evaluation | LAG = 1, lambda_data = 0.3, lambda_phys = 0.7 ---
# Mean Squared Error (MSE):   113.1992
# Mean Absolute Error (MAE):  8.1826
# Root Mean Squared Error (RMSE): 10.6395
# Normalized Mean Squared Error (NMSE): 0.6565
#
# >>> Training MLP+Physics | LAG = 1, lambda_data = 0.5, lambda_phys = 0.5
#
# --- First 10 Samples: True vs Physics AQI (Targeted Day) ---
# Sample 01: True=26.000, Physics=25.556, Diff=0.444
# Sample 02: True=52.000, Physics=52.112, Diff=0.112
# Sample 03: True=29.000, Physics=29.444, Diff=0.444
# Sample 04: True=32.667, Physics=32.778, Diff=0.111
# Sample 05: True=39.000, Physics=39.444, Diff=0.444
# Sample 06: True=42.000, Physics=41.667, Diff=0.333
# Sample 07: True=61.000, Physics=61.145, Diff=0.145
# Sample 08: True=23.000, Physics=23.333, Diff=0.333
# Sample 09: True=31.000, Physics=31.111, Diff=0.111
# Sample 10: True=49.000, Physics=49.444, Diff=0.444
# Epoch 1: Data Loss = 2325.867920, Physics Loss = 2353.988770, Total Loss = 2339.928223
# Epoch 2: Data Loss = 2322.986572, Physics Loss = 2351.092041, Total Loss = 2337.039307
# Epoch 3: Data Loss = 2320.198730, Physics Loss = 2348.289307, Total Loss = 2334.244141
# Epoch 4: Data Loss = 2317.485352, Physics Loss = 2345.561035, Total Loss = 2331.523193
# Epoch 5: Data Loss = 2314.849854, Physics Loss = 2342.911377, Total Loss = 2328.880615
# Epoch 200/3000, Total Loss = 566.970581, Data Loss = 561.078430, Physics Loss = 572.862793
# Epoch 400/3000, Total Loss = 199.397705, Data Loss = 197.316147, Physics Loss = 201.479263
# Epoch 600/3000, Total Loss = 165.272095, Data Loss = 163.983353, Physics Loss = 166.560852
# Epoch 800/3000, Total Loss = 162.907166, Data Loss = 161.673523, Physics Loss = 164.140793
# Epoch 1000/3000, Total Loss = 162.107407, Data Loss = 160.888000, Physics Loss = 163.326813
# Epoch 1200/3000, Total Loss = 161.645538, Data Loss = 160.435791, Physics Loss = 162.855270
# Epoch 1400/3000, Total Loss = 161.342163, Data Loss = 160.141129, Physics Loss = 162.543213
# Epoch 1600/3000, Total Loss = 161.145660, Data Loss = 159.955643, Physics Loss = 162.335663
# Epoch 1800/3000, Total Loss = 161.004456, Data Loss = 159.825073, Physics Loss = 162.183853
# Epoch 2000/3000, Total Loss = 160.890808, Data Loss = 159.719070, Physics Loss = 162.062531
# Epoch 2200/3000, Total Loss = 160.375473, Data Loss = 159.213669, Physics Loss = 161.537277
# Epoch 2400/3000, Total Loss = 159.956757, Data Loss = 158.805374, Physics Loss = 161.108139
# Epoch 2600/3000, Total Loss = 159.768539, Data Loss = 158.621277, Physics Loss = 160.915802
# Epoch 2800/3000, Total Loss = 159.652100, Data Loss = 158.505386, Physics Loss = 160.798813
# Epoch 3000/3000, Total Loss = 159.572693, Data Loss = 158.425583, Physics Loss = 160.719818
#
# --- Evaluation | LAG = 1, lambda_data = 0.5, lambda_phys = 0.5 ---
# Mean Squared Error (MSE):   113.2744
# Mean Absolute Error (MAE):  8.1918
# Root Mean Squared Error (RMSE): 10.6430
# Normalized Mean Squared Error (NMSE): 0.6570
#
# >>> Training MLP+Physics | LAG = 1, lambda_data = 0.7, lambda_phys = 0.3
#
# --- First 10 Samples: True vs Physics AQI (Targeted Day) ---
# Sample 01: True=26.000, Physics=25.556, Diff=0.444
# Sample 02: True=52.000, Physics=52.112, Diff=0.112
# Sample 03: True=29.000, Physics=29.444, Diff=0.444
# Sample 04: True=32.667, Physics=32.778, Diff=0.111
# Sample 05: True=39.000, Physics=39.444, Diff=0.444
# Sample 06: True=42.000, Physics=41.667, Diff=0.333
# Sample 07: True=61.000, Physics=61.145, Diff=0.145
# Sample 08: True=23.000, Physics=23.333, Diff=0.333
# Sample 09: True=31.000, Physics=31.111, Diff=0.111
# Sample 10: True=49.000, Physics=49.444, Diff=0.444
# Epoch 1: Data Loss = 2325.867920, Physics Loss = 2353.988770, Total Loss = 2334.304199
# Epoch 2: Data Loss = 2322.986572, Physics Loss = 2351.092041, Total Loss = 2331.418213
# Epoch 3: Data Loss = 2320.198730, Physics Loss = 2348.289307, Total Loss = 2328.625977
# Epoch 4: Data Loss = 2317.485352, Physics Loss = 2345.561035, Total Loss = 2325.908203
# Epoch 5: Data Loss = 2314.849854, Physics Loss = 2342.911377, Total Loss = 2323.268311
# Epoch 200/3000, Total Loss = 564.815247, Data Loss = 561.277100, Physics Loss = 573.070923
# Epoch 400/3000, Total Loss = 198.741714, Data Loss = 197.484207, Physics Loss = 201.675934
# Epoch 600/3000, Total Loss = 164.767563, Data Loss = 163.984436, Physics Loss = 166.594879
# Epoch 800/3000, Total Loss = 162.415131, Data Loss = 161.664688, Physics Loss = 164.166153
# Epoch 1000/3000, Total Loss = 161.623734, Data Loss = 160.882477, Physics Loss = 163.353348
# Epoch 1200/3000, Total Loss = 161.165451, Data Loss = 160.429703, Physics Loss = 162.882187
# Epoch 1400/3000, Total Loss = 160.870377, Data Loss = 160.139679, Physics Loss = 162.575333
# Epoch 1600/3000, Total Loss = 160.674866, Data Loss = 159.950302, Physics Loss = 162.365524
# Epoch 1800/3000, Total Loss = 160.538086, Data Loss = 159.820038, Physics Loss = 162.213547
# Epoch 2000/3000, Total Loss = 160.455994, Data Loss = 159.740631, Physics Loss = 162.125168
# Epoch 2200/3000, Total Loss = 159.955597, Data Loss = 159.253403, Physics Loss = 161.594070
# Epoch 2400/3000, Total Loss = 159.513840, Data Loss = 158.811951, Physics Loss = 161.151566
# Epoch 2600/3000, Total Loss = 159.316116, Data Loss = 158.617294, Physics Loss = 160.946701
# Epoch 2800/3000, Total Loss = 159.195068, Data Loss = 158.497421, Physics Loss = 160.822906
# Epoch 3000/3000, Total Loss = 159.113495, Data Loss = 158.413895, Physics Loss = 160.745865
#
# --- Evaluation | LAG = 1, lambda_data = 0.7, lambda_phys = 0.3 ---
# Mean Squared Error (MSE):   113.3739
# Mean Absolute Error (MAE):  8.2017
# Root Mean Squared Error (RMSE): 10.6477
# Normalized Mean Squared Error (NMSE): 0.6576
#
# >>> Training MLP+Physics | LAG = 1, lambda_data = 1.0, lambda_phys = 0.0
#
# --- First 10 Samples: True vs Physics AQI (Targeted Day) ---
# Sample 01: True=26.000, Physics=25.556, Diff=0.444
# Sample 02: True=52.000, Physics=52.112, Diff=0.112
# Sample 03: True=29.000, Physics=29.444, Diff=0.444
# Sample 04: True=32.667, Physics=32.778, Diff=0.111
# Sample 05: True=39.000, Physics=39.444, Diff=0.444
# Sample 06: True=42.000, Physics=41.667, Diff=0.333
# Sample 07: True=61.000, Physics=61.145, Diff=0.145
# Sample 08: True=23.000, Physics=23.333, Diff=0.333
# Sample 09: True=31.000, Physics=31.111, Diff=0.111
# Sample 10: True=49.000, Physics=49.444, Diff=0.444
# Epoch 1: Data Loss = 2325.867920, Physics Loss = 2353.988770, Total Loss = 2325.867920
# Epoch 2: Data Loss = 2322.986572, Physics Loss = 2351.092041, Total Loss = 2322.986572
# Epoch 3: Data Loss = 2320.198730, Physics Loss = 2348.289307, Total Loss = 2320.198730
# Epoch 4: Data Loss = 2317.485352, Physics Loss = 2345.561035, Total Loss = 2317.485352
# Epoch 5: Data Loss = 2314.849854, Physics Loss = 2342.911377, Total Loss = 2314.849854
# Epoch 200/3000, Total Loss = 561.576050, Data Loss = 561.576050, Physics Loss = 573.384033
# Epoch 400/3000, Total Loss = 197.730835, Data Loss = 197.730835, Physics Loss = 201.964752
# Epoch 600/3000, Total Loss = 164.001740, Data Loss = 164.001740, Physics Loss = 166.660858
# Epoch 800/3000, Total Loss = 161.663712, Data Loss = 161.663712, Physics Loss = 164.220184
# Epoch 1000/3000, Total Loss = 160.885941, Data Loss = 160.885941, Physics Loss = 163.406754
# Epoch 1200/3000, Total Loss = 160.432465, Data Loss = 160.432465, Physics Loss = 162.934937
# Epoch 1400/3000, Total Loss = 160.148453, Data Loss = 160.148453, Physics Loss = 162.633621
# Epoch 1600/3000, Total Loss = 159.954041, Data Loss = 159.954041, Physics Loss = 162.418549
# Epoch 1800/3000, Total Loss = 159.825043, Data Loss = 159.825043, Physics Loss = 162.271011
# Epoch 2000/3000, Total Loss = 159.747513, Data Loss = 159.747513, Physics Loss = 162.182510
# Epoch 2200/3000, Total Loss = 159.307251, Data Loss = 159.307251, Physics Loss = 161.700302
# Epoch 2400/3000, Total Loss = 158.838211, Data Loss = 158.838211, Physics Loss = 161.228149
# Epoch 2600/3000, Total Loss = 158.625427, Data Loss = 158.625427, Physics Loss = 161.005829
# Epoch 2800/3000, Total Loss = 158.496811, Data Loss = 158.496811, Physics Loss = 160.870453
# Epoch 3000/3000, Total Loss = 158.411743, Data Loss = 158.411743, Physics Loss = 160.787979
#
# --- Evaluation | LAG = 1, lambda_data = 1.0, lambda_phys = 0.0 ---
# Mean Squared Error (MSE):   113.4974
# Mean Absolute Error (MAE):  8.2149
# Root Mean Squared Error (RMSE): 10.6535
# Normalized Mean Squared Error (NMSE): 0.6583
#
# ========================================
# Preparing supervised dataset for LAG = 7
# ========================================
#
# --- Supervised Data (Head) ---
#         DATE  Daily_Mean_PM  Daily_AQI_Value  AQI_Targeted_Value_LAG_7  \
# 0 2022-01-01            6.1        34.000000                      61.0
# 1 2022-01-02            4.6        26.000000                      23.0
# 2 2022-01-03            9.6        52.000000                      31.0
# 3 2022-01-04            5.3        29.000000                      49.0
# 4 2022-01-05            5.9        32.666667                      35.0
#
#    PM_Targeted_Value_LAG_7
# 0                14.466667
# 1                 4.200000
# 2                 5.600000
# 3                 8.900000
# 4                 6.300000
# --------------------------------------------------
# Shape: (1087, 5)
#
# >>> Training MLP+Physics | LAG = 7, lambda_data = 0.0, lambda_phys = 1.0
#
# --- First 10 Samples: True vs Physics AQI (Targeted Day) ---
# Sample 01: True=61.000, Physics=61.145, Diff=0.145
# Sample 02: True=23.000, Physics=23.333, Diff=0.333
# Sample 03: True=31.000, Physics=31.111, Diff=0.111
# Sample 04: True=49.000, Physics=49.444, Diff=0.444
# Sample 05: True=35.000, Physics=35.000, Diff=0.000
# Sample 06: True=43.000, Physics=42.778, Diff=0.222
# Sample 07: True=52.667, Physics=53.844, Diff=1.178
# Sample 08: True=27.000, Physics=26.667, Diff=0.333
# Sample 09: True=55.000, Physics=54.710, Diff=0.290
# Sample 10: True=64.250, Physics=64.223, Diff=0.027
# Epoch 1: Data Loss = 2335.635254, Physics Loss = 2363.967773, Total Loss = 2363.967773
# Epoch 2: Data Loss = 2332.758789, Physics Loss = 2361.074463, Total Loss = 2361.074463
# Epoch 3: Data Loss = 2329.976807, Physics Loss = 2358.276855, Total Loss = 2358.276855
# Epoch 4: Data Loss = 2327.276367, Physics Loss = 2355.560791, Total Loss = 2355.560791
# Epoch 5: Data Loss = 2324.653076, Physics Loss = 2352.922363, Total Loss = 2352.922363
# Epoch 200/3000, Total Loss = 595.495483, Data Loss = 584.690857, Physics Loss = 595.495483
# Epoch 400/3000, Total Loss = 257.487640, Data Loss = 253.313934, Physics Loss = 257.487640
# Epoch 600/3000, Total Loss = 235.405609, Data Loss = 232.219666, Physics Loss = 235.405609
# Epoch 800/3000, Total Loss = 233.015244, Data Loss = 229.818329, Physics Loss = 233.015244
# Epoch 1000/3000, Total Loss = 232.330124, Data Loss = 229.115829, Physics Loss = 232.330124
# Epoch 1200/3000, Total Loss = 232.124222, Data Loss = 228.907043, Physics Loss = 232.124222
# Epoch 1400/3000, Total Loss = 232.031631, Data Loss = 228.813416, Physics Loss = 232.031631
# Epoch 1600/3000, Total Loss = 231.958649, Data Loss = 228.739746, Physics Loss = 231.958649
# Epoch 1800/3000, Total Loss = 231.880066, Data Loss = 228.660995, Physics Loss = 231.880066
# Epoch 2000/3000, Total Loss = 231.806320, Data Loss = 228.586456, Physics Loss = 231.806320
# Epoch 2200/3000, Total Loss = 231.733170, Data Loss = 228.515320, Physics Loss = 231.733170
# Epoch 2400/3000, Total Loss = 231.659256, Data Loss = 228.440659, Physics Loss = 231.659256
# Epoch 2600/3000, Total Loss = 231.579926, Data Loss = 228.360687, Physics Loss = 231.579926
# Epoch 2800/3000, Total Loss = 231.493118, Data Loss = 228.276825, Physics Loss = 231.493118
# Epoch 3000/3000, Total Loss = 231.404617, Data Loss = 228.192261, Physics Loss = 231.404617
#
# --- Evaluation | LAG = 7, lambda_data = 0.0, lambda_phys = 1.0 ---
# Mean Squared Error (MSE):   172.5921
# Mean Absolute Error (MAE):  10.1783
# Root Mean Squared Error (RMSE): 13.1374
# Normalized Mean Squared Error (NMSE): 1.0228
#
# >>> Training MLP+Physics | LAG = 7, lambda_data = 0.3, lambda_phys = 0.7
#
# --- First 10 Samples: True vs Physics AQI (Targeted Day) ---
# Sample 01: True=61.000, Physics=61.145, Diff=0.145
# Sample 02: True=23.000, Physics=23.333, Diff=0.333
# Sample 03: True=31.000, Physics=31.111, Diff=0.111
# Sample 04: True=49.000, Physics=49.444, Diff=0.444
# Sample 05: True=35.000, Physics=35.000, Diff=0.000
# Sample 06: True=43.000, Physics=42.778, Diff=0.222
# Sample 07: True=52.667, Physics=53.844, Diff=1.178
# Sample 08: True=27.000, Physics=26.667, Diff=0.333
# Sample 09: True=55.000, Physics=54.710, Diff=0.290
# Sample 10: True=64.250, Physics=64.223, Diff=0.027
# Epoch 1: Data Loss = 2335.635254, Physics Loss = 2363.967773, Total Loss = 2355.468018
# Epoch 2: Data Loss = 2332.758789, Physics Loss = 2361.074463, Total Loss = 2352.579590
# Epoch 3: Data Loss = 2329.976807, Physics Loss = 2358.276855, Total Loss = 2349.786865
# Epoch 4: Data Loss = 2327.276367, Physics Loss = 2355.560791, Total Loss = 2347.075439
# Epoch 5: Data Loss = 2324.652832, Physics Loss = 2352.922363, Total Loss = 2344.441406
# Epoch 200/3000, Total Loss = 592.560974, Data Loss = 584.986450, Physics Loss = 595.807190
# Epoch 400/3000, Total Loss = 256.371796, Data Loss = 253.422211, Physics Loss = 257.635925
# Epoch 600/3000, Total Loss = 234.375656, Data Loss = 232.109680, Physics Loss = 235.346786
# Epoch 800/3000, Total Loss = 231.876678, Data Loss = 229.599731, Physics Loss = 232.852509
# Epoch 1000/3000, Total Loss = 231.345078, Data Loss = 229.063446, Physics Loss = 232.322906
# Epoch 1200/3000, Total Loss = 231.160446, Data Loss = 228.878220, Physics Loss = 232.138535
# Epoch 1400/3000, Total Loss = 231.068481, Data Loss = 228.783798, Physics Loss = 232.047623
# Epoch 1600/3000, Total Loss = 230.993866, Data Loss = 228.708557, Physics Loss = 231.973282
# Epoch 1800/3000, Total Loss = 230.915634, Data Loss = 228.629639, Physics Loss = 231.895340
# Epoch 2000/3000, Total Loss = 230.839432, Data Loss = 228.553146, Physics Loss = 231.819275
# Epoch 2200/3000, Total Loss = 230.766083, Data Loss = 228.479477, Physics Loss = 231.746063
# Epoch 2400/3000, Total Loss = 230.690948, Data Loss = 228.406937, Physics Loss = 231.669785
# Epoch 2600/3000, Total Loss = 230.610565, Data Loss = 228.329117, Physics Loss = 231.588318
# Epoch 2800/3000, Total Loss = 230.524323, Data Loss = 228.238541, Physics Loss = 231.503922
# Epoch 3000/3000, Total Loss = 230.432922, Data Loss = 228.149414, Physics Loss = 231.411575
#
# --- Evaluation | LAG = 7, lambda_data = 0.3, lambda_phys = 0.7 ---
# Mean Squared Error (MSE):   172.9433
# Mean Absolute Error (MAE):  10.1934
# Root Mean Squared Error (RMSE): 13.1508
# Normalized Mean Squared Error (NMSE): 1.0249
#
# >>> Training MLP+Physics | LAG = 7, lambda_data = 0.5, lambda_phys = 0.5
#
# --- First 10 Samples: True vs Physics AQI (Targeted Day) ---
# Sample 01: True=61.000, Physics=61.145, Diff=0.145
# Sample 02: True=23.000, Physics=23.333, Diff=0.333
# Sample 03: True=31.000, Physics=31.111, Diff=0.111
# Sample 04: True=49.000, Physics=49.444, Diff=0.444
# Sample 05: True=35.000, Physics=35.000, Diff=0.000
# Sample 06: True=43.000, Physics=42.778, Diff=0.222
# Sample 07: True=52.667, Physics=53.844, Diff=1.178
# Sample 08: True=27.000, Physics=26.667, Diff=0.333
# Sample 09: True=55.000, Physics=54.710, Diff=0.290
# Sample 10: True=64.250, Physics=64.223, Diff=0.027
# Epoch 1: Data Loss = 2335.635254, Physics Loss = 2363.967773, Total Loss = 2349.801514
# Epoch 2: Data Loss = 2332.758789, Physics Loss = 2361.074463, Total Loss = 2346.916504
# Epoch 3: Data Loss = 2329.976807, Physics Loss = 2358.276855, Total Loss = 2344.126953
# Epoch 4: Data Loss = 2327.276367, Physics Loss = 2355.560791, Total Loss = 2341.418457
# Epoch 5: Data Loss = 2324.652832, Physics Loss = 2352.922363, Total Loss = 2338.787598
# Epoch 200/3000, Total Loss = 590.596680, Data Loss = 585.180664, Physics Loss = 596.012756
# Epoch 400/3000, Total Loss = 255.597839, Data Loss = 253.477417, Physics Loss = 257.718262
# Epoch 600/3000, Total Loss = 233.715378, Data Loss = 232.082428, Physics Loss = 235.348328
# Epoch 800/3000, Total Loss = 231.203186, Data Loss = 229.560379, Physics Loss = 232.845978
# Epoch 1000/3000, Total Loss = 230.689087, Data Loss = 229.045502, Physics Loss = 232.332672
# Epoch 1200/3000, Total Loss = 230.505844, Data Loss = 228.860397, Physics Loss = 232.151291
# Epoch 1400/3000, Total Loss = 230.415619, Data Loss = 228.769363, Physics Loss = 232.061874
# Epoch 1600/3000, Total Loss = 230.341232, Data Loss = 228.693771, Physics Loss = 231.988693
# Epoch 1800/3000, Total Loss = 230.262146, Data Loss = 228.613998, Physics Loss = 231.910278
# Epoch 2000/3000, Total Loss = 230.183182, Data Loss = 228.534775, Physics Loss = 231.831589
# Epoch 2200/3000, Total Loss = 230.107727, Data Loss = 228.458969, Physics Loss = 231.756485
# Epoch 2400/3000, Total Loss = 230.029587, Data Loss = 228.380463, Physics Loss = 231.678711
# Epoch 2600/3000, Total Loss = 229.948898, Data Loss = 228.301025, Physics Loss = 231.596771
# Epoch 2800/3000, Total Loss = 229.863037, Data Loss = 228.215652, Physics Loss = 231.510422
# Epoch 3000/3000, Total Loss = 229.770401, Data Loss = 228.123398, Physics Loss = 231.417404
#
# --- Evaluation | LAG = 7, lambda_data = 0.5, lambda_phys = 0.5 ---
# Mean Squared Error (MSE):   173.1626
# Mean Absolute Error (MAE):  10.2015
# Root Mean Squared Error (RMSE): 13.1591
# Normalized Mean Squared Error (NMSE): 1.0262
#
# >>> Training MLP+Physics | LAG = 7, lambda_data = 0.7, lambda_phys = 0.3
#
# --- First 10 Samples: True vs Physics AQI (Targeted Day) ---
# Sample 01: True=61.000, Physics=61.145, Diff=0.145
# Sample 02: True=23.000, Physics=23.333, Diff=0.333
# Sample 03: True=31.000, Physics=31.111, Diff=0.111
# Sample 04: True=49.000, Physics=49.444, Diff=0.444
# Sample 05: True=35.000, Physics=35.000, Diff=0.000
# Sample 06: True=43.000, Physics=42.778, Diff=0.222
# Sample 07: True=52.667, Physics=53.844, Diff=1.178
# Sample 08: True=27.000, Physics=26.667, Diff=0.333
# Sample 09: True=55.000, Physics=54.710, Diff=0.290
# Sample 10: True=64.250, Physics=64.223, Diff=0.027
# Epoch 1: Data Loss = 2335.635254, Physics Loss = 2363.967773, Total Loss = 2344.135010
# Epoch 2: Data Loss = 2332.758789, Physics Loss = 2361.074463, Total Loss = 2341.253418
# Epoch 3: Data Loss = 2329.976807, Physics Loss = 2358.276855, Total Loss = 2338.466797
# Epoch 4: Data Loss = 2327.276367, Physics Loss = 2355.560791, Total Loss = 2335.761719
# Epoch 5: Data Loss = 2324.652832, Physics Loss = 2352.922363, Total Loss = 2333.133789
# Epoch 200/3000, Total Loss = 588.629517, Data Loss = 585.376587, Physics Loss = 596.219666
# Epoch 400/3000, Total Loss = 254.822906, Data Loss = 253.542603, Physics Loss = 257.810272
# Epoch 600/3000, Total Loss = 233.042801, Data Loss = 232.052750, Physics Loss = 235.352936
# Epoch 800/3000, Total Loss = 230.523773, Data Loss = 229.529739, Physics Loss = 232.843185
# Epoch 1000/3000, Total Loss = 230.027039, Data Loss = 229.031540, Physics Loss = 232.349869
# Epoch 1200/3000, Total Loss = 229.842316, Data Loss = 228.846008, Physics Loss = 232.167053
# Epoch 1400/3000, Total Loss = 229.750092, Data Loss = 228.752945, Physics Loss = 232.076782
# Epoch 1600/3000, Total Loss = 229.666016, Data Loss = 228.668259, Physics Loss = 231.994095
# Epoch 1800/3000, Total Loss = 229.580017, Data Loss = 228.582184, Physics Loss = 231.908325
# Epoch 2000/3000, Total Loss = 229.494415, Data Loss = 228.496292, Physics Loss = 231.823349
# Epoch 2200/3000, Total Loss = 229.418091, Data Loss = 228.420364, Physics Loss = 231.746140
# Epoch 2400/3000, Total Loss = 229.341370, Data Loss = 228.342239, Physics Loss = 231.672684
# Epoch 2600/3000, Total Loss = 229.266510, Data Loss = 228.270233, Physics Loss = 231.591202
# Epoch 2800/3000, Total Loss = 229.186798, Data Loss = 228.189545, Physics Loss = 231.513718
# Epoch 3000/3000, Total Loss = 229.104645, Data Loss = 228.107956, Physics Loss = 231.430237
#
# --- Evaluation | LAG = 7, lambda_data = 0.7, lambda_phys = 0.3 ---
# Mean Squared Error (MSE):   173.5139
# Mean Absolute Error (MAE):  10.2152
# Root Mean Squared Error (RMSE): 13.1725
# Normalized Mean Squared Error (NMSE): 1.0283
#
# >>> Training MLP+Physics | LAG = 7, lambda_data = 1.0, lambda_phys = 0.0
#
# --- First 10 Samples: True vs Physics AQI (Targeted Day) ---
# Sample 01: True=61.000, Physics=61.145, Diff=0.145
# Sample 02: True=23.000, Physics=23.333, Diff=0.333
# Sample 03: True=31.000, Physics=31.111, Diff=0.111
# Sample 04: True=49.000, Physics=49.444, Diff=0.444
# Sample 05: True=35.000, Physics=35.000, Diff=0.000
# Sample 06: True=43.000, Physics=42.778, Diff=0.222
# Sample 07: True=52.667, Physics=53.844, Diff=1.178
# Sample 08: True=27.000, Physics=26.667, Diff=0.333
# Sample 09: True=55.000, Physics=54.710, Diff=0.290
# Sample 10: True=64.250, Physics=64.223, Diff=0.027
# Epoch 1: Data Loss = 2335.635254, Physics Loss = 2363.967773, Total Loss = 2335.635254
# Epoch 2: Data Loss = 2332.758789, Physics Loss = 2361.074463, Total Loss = 2332.758789
# Epoch 3: Data Loss = 2329.976807, Physics Loss = 2358.276855, Total Loss = 2329.976807
# Epoch 4: Data Loss = 2327.276367, Physics Loss = 2355.560791, Total Loss = 2327.276367
# Epoch 5: Data Loss = 2324.652832, Physics Loss = 2352.922363, Total Loss = 2324.652832
# Epoch 200/3000, Total Loss = 585.673096, Data Loss = 585.673096, Physics Loss = 596.533081
# Epoch 400/3000, Total Loss = 253.645493, Data Loss = 253.645493, Physics Loss = 257.953461
# Epoch 600/3000, Total Loss = 232.018005, Data Loss = 232.018005, Physics Loss = 235.360352
# Epoch 800/3000, Total Loss = 229.499557, Data Loss = 229.499557, Physics Loss = 232.860977
# Epoch 1000/3000, Total Loss = 229.021912, Data Loss = 229.021912, Physics Loss = 232.386520
# Epoch 1200/3000, Total Loss = 228.836319, Data Loss = 228.836319, Physics Loss = 232.201843
# Epoch 1400/3000, Total Loss = 228.740158, Data Loss = 228.740158, Physics Loss = 232.110092
# Epoch 1600/3000, Total Loss = 228.650986, Data Loss = 228.650986, Physics Loss = 232.022873
# Epoch 1800/3000, Total Loss = 228.568253, Data Loss = 228.568253, Physics Loss = 231.940536
# Epoch 2000/3000, Total Loss = 228.490524, Data Loss = 228.490524, Physics Loss = 231.863586
# Epoch 2200/3000, Total Loss = 228.412460, Data Loss = 228.412460, Physics Loss = 231.789444
# Epoch 2400/3000, Total Loss = 228.339294, Data Loss = 228.339294, Physics Loss = 231.712021
# Epoch 2600/3000, Total Loss = 228.264633, Data Loss = 228.264633, Physics Loss = 231.638306
# Epoch 2800/3000, Total Loss = 228.187531, Data Loss = 228.187531, Physics Loss = 231.559845
# Epoch 3000/3000, Total Loss = 228.106445, Data Loss = 228.106445, Physics Loss = 231.478851
#
# --- Evaluation | LAG = 7, lambda_data = 1.0, lambda_phys = 0.0 ---
# Mean Squared Error (MSE):   173.8895
# Mean Absolute Error (MAE):  10.2289
# Root Mean Squared Error (RMSE): 13.1867
# Normalized Mean Squared Error (NMSE): 1.0305
#
# ========================================
# Preparing supervised dataset for LAG = 14
# ========================================
#
# --- Supervised Data (Head) ---
#         DATE  Daily_Mean_PM  Daily_AQI_Value  AQI_Targeted_Value_LAG_14  \
# 0 2022-01-01            6.1        34.000000                      27.00
# 1 2022-01-02            4.6        26.000000                      55.00
# 2 2022-01-03            9.6        52.000000                      64.25
# 3 2022-01-04            5.3        29.000000                      37.00
# 4 2022-01-05            5.9        32.666667                      44.00
#
#    PM_Targeted_Value_LAG_14
# 0                     4.800
# 1                    11.000
# 2                    16.125
# 3                     6.600
# 4                     7.900
# --------------------------------------------------
# Shape: (1080, 5)
#
# >>> Training MLP+Physics | LAG = 14, lambda_data = 0.0, lambda_phys = 1.0
#
# --- First 10 Samples: True vs Physics AQI (Targeted Day) ---
# Sample 01: True=27.000, Physics=26.667, Diff=0.333
# Sample 02: True=55.000, Physics=54.710, Diff=0.290
# Sample 03: True=64.250, Physics=64.223, Diff=0.027
# Sample 04: True=37.000, Physics=36.667, Diff=0.333
# Sample 05: True=44.000, Physics=43.889, Diff=0.111
# Sample 06: True=9.000, Physics=8.704, Diff=0.296
# Sample 07: True=17.000, Physics=16.667, Diff=0.333
# Sample 08: True=55.000, Physics=55.267, Diff=0.267
# Sample 09: True=50.333, Physics=51.493, Diff=1.160
# Sample 10: True=26.000, Physics=25.556, Diff=0.444
# Epoch 1: Data Loss = 2348.386963, Physics Loss = 2376.447510, Total Loss = 2376.447510
# Epoch 2: Data Loss = 2345.531494, Physics Loss = 2373.575195, Total Loss = 2373.575195
# Epoch 3: Data Loss = 2342.770020, Physics Loss = 2370.797363, Total Loss = 2370.797363
# Epoch 4: Data Loss = 2340.089355, Physics Loss = 2368.100586, Total Loss = 2368.100586
# Epoch 5: Data Loss = 2337.483154, Physics Loss = 2365.478760, Total Loss = 2365.478760
# Epoch 200/3000, Total Loss = 617.663940, Data Loss = 607.724304, Physics Loss = 617.663940
# Epoch 400/3000, Total Loss = 266.755249, Data Loss = 262.827393, Physics Loss = 266.755249
# Epoch 600/3000, Total Loss = 242.247238, Data Loss = 239.185333, Physics Loss = 242.247238
# Epoch 800/3000, Total Loss = 240.506073, Data Loss = 237.519180, Physics Loss = 240.506073
# Epoch 1000/3000, Total Loss = 239.927994, Data Loss = 236.952698, Physics Loss = 239.927994
# Epoch 1200/3000, Total Loss = 239.548721, Data Loss = 236.578018, Physics Loss = 239.548721
# Epoch 1400/3000, Total Loss = 239.265167, Data Loss = 236.297363, Physics Loss = 239.265167
# Epoch 1600/3000, Total Loss = 239.021393, Data Loss = 236.057449, Physics Loss = 239.021393
# Epoch 1800/3000, Total Loss = 238.795883, Data Loss = 235.832825, Physics Loss = 238.795883
# Epoch 2000/3000, Total Loss = 238.568817, Data Loss = 235.602127, Physics Loss = 238.568817
# Epoch 2200/3000, Total Loss = 238.297668, Data Loss = 235.324829, Physics Loss = 238.297668
# Epoch 2400/3000, Total Loss = 238.063980, Data Loss = 235.097519, Physics Loss = 238.063980
# Epoch 2600/3000, Total Loss = 237.832001, Data Loss = 234.865906, Physics Loss = 237.832001
# Epoch 2800/3000, Total Loss = 237.588562, Data Loss = 234.627747, Physics Loss = 237.588562
# Epoch 3000/3000, Total Loss = 237.322189, Data Loss = 234.372162, Physics Loss = 237.322189
#
# --- Evaluation | LAG = 14, lambda_data = 0.0, lambda_phys = 1.0 ---
# Mean Squared Error (MSE):   160.7919
# Mean Absolute Error (MAE):  10.0925
# Root Mean Squared Error (RMSE): 12.6804
# Normalized Mean Squared Error (NMSE): 1.0228
#
# >>> Training MLP+Physics | LAG = 14, lambda_data = 0.3, lambda_phys = 0.7
#
# --- First 10 Samples: True vs Physics AQI (Targeted Day) ---
# Sample 01: True=27.000, Physics=26.667, Diff=0.333
# Sample 02: True=55.000, Physics=54.710, Diff=0.290
# Sample 03: True=64.250, Physics=64.223, Diff=0.027
# Sample 04: True=37.000, Physics=36.667, Diff=0.333
# Sample 05: True=44.000, Physics=43.889, Diff=0.111
# Sample 06: True=9.000, Physics=8.704, Diff=0.296
# Sample 07: True=17.000, Physics=16.667, Diff=0.333
# Sample 08: True=55.000, Physics=55.267, Diff=0.267
# Sample 09: True=50.333, Physics=51.493, Diff=1.160
# Sample 10: True=26.000, Physics=25.556, Diff=0.444
# Epoch 1: Data Loss = 2348.386963, Physics Loss = 2376.447510, Total Loss = 2368.029297
# Epoch 2: Data Loss = 2345.531494, Physics Loss = 2373.575195, Total Loss = 2365.162109
# Epoch 3: Data Loss = 2342.770020, Physics Loss = 2370.797363, Total Loss = 2362.389160
# Epoch 4: Data Loss = 2340.089355, Physics Loss = 2368.100586, Total Loss = 2359.697266
# Epoch 5: Data Loss = 2337.482910, Physics Loss = 2365.478760, Total Loss = 2357.080078
# Epoch 200/3000, Total Loss = 614.937317, Data Loss = 607.966736, Physics Loss = 617.924744
# Epoch 400/3000, Total Loss = 265.608093, Data Loss = 262.830353, Physics Loss = 266.798553
# Epoch 600/3000, Total Loss = 241.322647, Data Loss = 239.152206, Physics Loss = 242.252838
# Epoch 800/3000, Total Loss = 239.602051, Data Loss = 237.480728, Physics Loss = 240.511200
# Epoch 1000/3000, Total Loss = 239.030121, Data Loss = 236.916138, Physics Loss = 239.936111
# Epoch 1200/3000, Total Loss = 238.651703, Data Loss = 236.541046, Physics Loss = 239.556259
# Epoch 1400/3000, Total Loss = 238.373016, Data Loss = 236.264664, Physics Loss = 239.276596
# Epoch 1600/3000, Total Loss = 238.129395, Data Loss = 236.022461, Physics Loss = 239.032364
# Epoch 1800/3000, Total Loss = 237.889359, Data Loss = 235.779572, Physics Loss = 238.793564
# Epoch 2000/3000, Total Loss = 237.629547, Data Loss = 235.517593, Physics Loss = 238.534683
# Epoch 2200/3000, Total Loss = 237.363922, Data Loss = 235.252335, Physics Loss = 238.268875
# Epoch 2400/3000, Total Loss = 237.146088, Data Loss = 235.032944, Physics Loss = 238.051727
# Epoch 2600/3000, Total Loss = 236.922165, Data Loss = 234.808090, Physics Loss = 237.828201
# Epoch 2800/3000, Total Loss = 236.678650, Data Loss = 234.572815, Physics Loss = 237.581161
# Epoch 3000/3000, Total Loss = 236.384918, Data Loss = 234.280151, Physics Loss = 237.286942
#
# --- Evaluation | LAG = 14, lambda_data = 0.3, lambda_phys = 0.7 ---
# Mean Squared Error (MSE):   161.1292
# Mean Absolute Error (MAE):  10.1092
# Root Mean Squared Error (RMSE): 12.6937
# Normalized Mean Squared Error (NMSE): 1.0249
#
# >>> Training MLP+Physics | LAG = 14, lambda_data = 0.5, lambda_phys = 0.5
#
# --- First 10 Samples: True vs Physics AQI (Targeted Day) ---
# Sample 01: True=27.000, Physics=26.667, Diff=0.333
# Sample 02: True=55.000, Physics=54.710, Diff=0.290
# Sample 03: True=64.250, Physics=64.223, Diff=0.027
# Sample 04: True=37.000, Physics=36.667, Diff=0.333
# Sample 05: True=44.000, Physics=43.889, Diff=0.111
# Sample 06: True=9.000, Physics=8.704, Diff=0.296
# Sample 07: True=17.000, Physics=16.667, Diff=0.333
# Sample 08: True=55.000, Physics=55.267, Diff=0.267
# Sample 09: True=50.333, Physics=51.493, Diff=1.160
# Sample 10: True=26.000, Physics=25.556, Diff=0.444
# Epoch 1: Data Loss = 2348.386963, Physics Loss = 2376.447510, Total Loss = 2362.417236
# Epoch 2: Data Loss = 2345.531494, Physics Loss = 2373.575195, Total Loss = 2359.553223
# Epoch 3: Data Loss = 2342.770020, Physics Loss = 2370.797363, Total Loss = 2356.783691
# Epoch 4: Data Loss = 2340.089355, Physics Loss = 2368.100586, Total Loss = 2354.094971
# Epoch 5: Data Loss = 2337.483154, Physics Loss = 2365.478760, Total Loss = 2351.480957
# Epoch 200/3000, Total Loss = 613.116028, Data Loss = 608.130798, Physics Loss = 618.101257
# Epoch 400/3000, Total Loss = 264.836182, Data Loss = 262.838745, Physics Loss = 266.833588
# Epoch 600/3000, Total Loss = 240.693115, Data Loss = 239.123016, Physics Loss = 242.263199
# Epoch 800/3000, Total Loss = 238.899780, Data Loss = 237.362045, Physics Loss = 240.437515
# Epoch 1000/3000, Total Loss = 238.228516, Data Loss = 236.698746, Physics Loss = 239.758286
# Epoch 1200/3000, Total Loss = 237.846359, Data Loss = 236.319931, Physics Loss = 239.372787
# Epoch 1400/3000, Total Loss = 237.547867, Data Loss = 236.021255, Physics Loss = 239.074478
# Epoch 1600/3000, Total Loss = 237.307129, Data Loss = 235.781128, Physics Loss = 238.833145
# Epoch 1800/3000, Total Loss = 237.102386, Data Loss = 235.574615, Physics Loss = 238.630157
# Epoch 2000/3000, Total Loss = 236.875290, Data Loss = 235.348068, Physics Loss = 238.402512
# Epoch 2200/3000, Total Loss = 236.650665, Data Loss = 235.122833, Physics Loss = 238.178497
# Epoch 2400/3000, Total Loss = 236.398727, Data Loss = 234.870895, Physics Loss = 237.926559
# Epoch 2600/3000, Total Loss = 236.119858, Data Loss = 234.593155, Physics Loss = 237.646561
# Epoch 2800/3000, Total Loss = 235.808578, Data Loss = 234.284668, Physics Loss = 237.332489
# Epoch 3000/3000, Total Loss = 235.494385, Data Loss = 233.972778, Physics Loss = 237.015991
#
# --- Evaluation | LAG = 14, lambda_data = 0.5, lambda_phys = 0.5 ---
# Mean Squared Error (MSE):   159.7588
# Mean Absolute Error (MAE):  10.0649
# Root Mean Squared Error (RMSE): 12.6396
# Normalized Mean Squared Error (NMSE): 1.0162
#
# >>> Training MLP+Physics | LAG = 14, lambda_data = 0.7, lambda_phys = 0.3
#
# --- First 10 Samples: True vs Physics AQI (Targeted Day) ---
# Sample 01: True=27.000, Physics=26.667, Diff=0.333
# Sample 02: True=55.000, Physics=54.710, Diff=0.290
# Sample 03: True=64.250, Physics=64.223, Diff=0.027
# Sample 04: True=37.000, Physics=36.667, Diff=0.333
# Sample 05: True=44.000, Physics=43.889, Diff=0.111
# Sample 06: True=9.000, Physics=8.704, Diff=0.296
# Sample 07: True=17.000, Physics=16.667, Diff=0.333
# Sample 08: True=55.000, Physics=55.267, Diff=0.267
# Sample 09: True=50.333, Physics=51.493, Diff=1.160
# Sample 10: True=26.000, Physics=25.556, Diff=0.444
# Epoch 1: Data Loss = 2348.386963, Physics Loss = 2376.447510, Total Loss = 2356.805176
# Epoch 2: Data Loss = 2345.531494, Physics Loss = 2373.575195, Total Loss = 2353.944580
# Epoch 3: Data Loss = 2342.770020, Physics Loss = 2370.797363, Total Loss = 2351.178223
# Epoch 4: Data Loss = 2340.089355, Physics Loss = 2368.100586, Total Loss = 2348.492676
# Epoch 5: Data Loss = 2337.482910, Physics Loss = 2365.478760, Total Loss = 2345.881836
# Epoch 200/3000, Total Loss = 611.288696, Data Loss = 608.293823, Physics Loss = 618.276794
# Epoch 400/3000, Total Loss = 264.060028, Data Loss = 262.853546, Physics Loss = 266.875122
# Epoch 600/3000, Total Loss = 240.084045, Data Loss = 239.131760, Physics Loss = 242.306061
# Epoch 800/3000, Total Loss = 238.286057, Data Loss = 237.354294, Physics Loss = 240.460144
# Epoch 1000/3000, Total Loss = 237.615753, Data Loss = 236.688858, Physics Loss = 239.778519
# Epoch 1200/3000, Total Loss = 237.232605, Data Loss = 236.306992, Physics Loss = 239.392349
# Epoch 1400/3000, Total Loss = 236.931519, Data Loss = 236.006714, Physics Loss = 239.089417
# Epoch 1600/3000, Total Loss = 236.691376, Data Loss = 235.766144, Physics Loss = 238.850220
# Epoch 1800/3000, Total Loss = 236.486496, Data Loss = 235.561142, Physics Loss = 238.645676
# Epoch 2000/3000, Total Loss = 236.258820, Data Loss = 235.332642, Physics Loss = 238.419861
# Epoch 2200/3000, Total Loss = 236.033783, Data Loss = 235.108765, Physics Loss = 238.192154
# Epoch 2400/3000, Total Loss = 235.781174, Data Loss = 234.855209, Physics Loss = 237.941727
# Epoch 2600/3000, Total Loss = 235.501526, Data Loss = 234.576569, Physics Loss = 237.659760
# Epoch 2800/3000, Total Loss = 235.191711, Data Loss = 234.268127, Physics Loss = 237.346771
# Epoch 3000/3000, Total Loss = 234.877228, Data Loss = 233.955536, Physics Loss = 237.027863
#
# --- Evaluation | LAG = 14, lambda_data = 0.7, lambda_phys = 0.3 ---
# Mean Squared Error (MSE):   159.8821
# Mean Absolute Error (MAE):  10.0713
# Root Mean Squared Error (RMSE): 12.6445
# Normalized Mean Squared Error (NMSE): 1.0170
#
# >>> Training MLP+Physics | LAG = 14, lambda_data = 1.0, lambda_phys = 0.0
#
# --- First 10 Samples: True vs Physics AQI (Targeted Day) ---
# Sample 01: True=27.000, Physics=26.667, Diff=0.333
# Sample 02: True=55.000, Physics=54.710, Diff=0.290
# Sample 03: True=64.250, Physics=64.223, Diff=0.027
# Sample 04: True=37.000, Physics=36.667, Diff=0.333
# Sample 05: True=44.000, Physics=43.889, Diff=0.111
# Sample 06: True=9.000, Physics=8.704, Diff=0.296
# Sample 07: True=17.000, Physics=16.667, Diff=0.333
# Sample 08: True=55.000, Physics=55.267, Diff=0.267
# Sample 09: True=50.333, Physics=51.493, Diff=1.160
# Sample 10: True=26.000, Physics=25.556, Diff=0.444
# Epoch 1: Data Loss = 2348.386963, Physics Loss = 2376.447510, Total Loss = 2348.386963
# Epoch 2: Data Loss = 2345.531494, Physics Loss = 2373.575195, Total Loss = 2345.531494
# Epoch 3: Data Loss = 2342.770020, Physics Loss = 2370.797363, Total Loss = 2342.770020
# Epoch 4: Data Loss = 2340.089355, Physics Loss = 2368.100586, Total Loss = 2340.089355
# Epoch 5: Data Loss = 2337.483154, Physics Loss = 2365.478760, Total Loss = 2337.483154
# Epoch 200/3000, Total Loss = 608.544128, Data Loss = 608.544128, Physics Loss = 618.545776
# Epoch 400/3000, Total Loss = 262.884796, Data Loss = 262.884796, Physics Loss = 266.946503
# Epoch 600/3000, Total Loss = 239.139130, Data Loss = 239.139130, Physics Loss = 242.358948
# Epoch 800/3000, Total Loss = 237.347687, Data Loss = 237.347687, Physics Loss = 240.499313
# Epoch 1000/3000, Total Loss = 236.681076, Data Loss = 236.681076, Physics Loss = 239.815887
# Epoch 1200/3000, Total Loss = 236.299042, Data Loss = 236.299042, Physics Loss = 239.429962
# Epoch 1400/3000, Total Loss = 235.993134, Data Loss = 235.993134, Physics Loss = 239.122421
# Epoch 1600/3000, Total Loss = 235.753113, Data Loss = 235.753113, Physics Loss = 238.882706
# Epoch 1800/3000, Total Loss = 235.546677, Data Loss = 235.546677, Physics Loss = 238.677521
# Epoch 2000/3000, Total Loss = 235.315506, Data Loss = 235.315506, Physics Loss = 238.445908
# Epoch 2200/3000, Total Loss = 235.086990, Data Loss = 235.086990, Physics Loss = 238.220230
# Epoch 2400/3000, Total Loss = 234.829865, Data Loss = 234.829865, Physics Loss = 237.966278
# Epoch 2600/3000, Total Loss = 234.546677, Data Loss = 234.546677, Physics Loss = 237.675217
# Epoch 2800/3000, Total Loss = 234.237320, Data Loss = 234.237320, Physics Loss = 237.360565
# Epoch 3000/3000, Total Loss = 233.925430, Data Loss = 233.925430, Physics Loss = 237.047089
#
# --- Evaluation | LAG = 14, lambda_data = 1.0, lambda_phys = 0.0 ---
# Mean Squared Error (MSE):   160.1181
# Mean Absolute Error (MAE):  10.0839
# Root Mean Squared Error (RMSE): 12.6538
# Normalized Mean Squared Error (NMSE): 1.0185
#
# ========================================
# Preparing supervised dataset for LAG = 30
# ========================================
#
# --- Supervised Data (Head) ---
#         DATE  Daily_Mean_PM  Daily_AQI_Value  AQI_Targeted_Value_LAG_30  \
# 0 2022-01-01            6.1        34.000000                  19.000000
# 1 2022-01-02            4.6        26.000000                  24.500000
# 2 2022-01-03            9.6        52.000000                  21.000000
# 3 2022-01-04            5.3        29.000000                   6.000000
# 4 2022-01-05            5.9        32.666667                  41.333333
#
#    PM_Targeted_Value_LAG_30
# 0                     3.500
# 1                     4.425
# 2                     3.700
# 3                     1.100
# 4                     7.500
# --------------------------------------------------
# Shape: (1064, 5)
#
# >>> Training MLP+Physics | LAG = 30, lambda_data = 0.0, lambda_phys = 1.0
#
# --- First 10 Samples: True vs Physics AQI (Targeted Day) ---
# Sample 01: True=19.000, Physics=19.444, Diff=0.444
# Sample 02: True=24.500, Physics=24.583, Diff=0.083
# Sample 03: True=21.000, Physics=20.556, Diff=0.444
# Sample 04: True=6.000, Physics=6.111, Diff=0.111
# Sample 05: True=41.333, Physics=41.667, Diff=0.333
# Sample 06: True=64.000, Physics=64.548, Diff=0.548
# Sample 07: True=32.000, Physics=31.667, Diff=0.333
# Sample 08: True=42.333, Physics=43.704, Diff=1.370
# Sample 09: True=25.500, Physics=25.556, Diff=0.056
# Sample 10: True=50.000, Physics=51.648, Diff=1.648
# Epoch 1: Data Loss = 2360.555176, Physics Loss = 2389.119629, Total Loss = 2389.119629
# Epoch 2: Data Loss = 2357.660400, Physics Loss = 2386.207031, Total Loss = 2386.207031
# Epoch 3: Data Loss = 2354.862793, Physics Loss = 2383.392578, Total Loss = 2383.392578
# Epoch 4: Data Loss = 2352.145752, Physics Loss = 2380.658936, Total Loss = 2380.658936
# Epoch 5: Data Loss = 2349.502197, Physics Loss = 2377.999512, Total Loss = 2377.999512
# Epoch 200/3000, Total Loss = 595.665161, Data Loss = 586.089172, Physics Loss = 595.665161
# Epoch 400/3000, Total Loss = 257.837372, Data Loss = 254.196350, Physics Loss = 257.837372
# Epoch 600/3000, Total Loss = 237.139206, Data Loss = 234.189560, Physics Loss = 237.139206
# Epoch 800/3000, Total Loss = 236.734924, Data Loss = 233.823730, Physics Loss = 236.734924
# Epoch 1000/3000, Total Loss = 236.467285, Data Loss = 233.567459, Physics Loss = 236.467285
# Epoch 1200/3000, Total Loss = 236.329910, Data Loss = 233.438919, Physics Loss = 236.329910
# Epoch 1400/3000, Total Loss = 236.222427, Data Loss = 233.336685, Physics Loss = 236.222427
# Epoch 1600/3000, Total Loss = 236.106522, Data Loss = 233.227448, Physics Loss = 236.106522
# Epoch 1800/3000, Total Loss = 235.962982, Data Loss = 233.088394, Physics Loss = 235.962982
# Epoch 2000/3000, Total Loss = 235.850098, Data Loss = 232.981583, Physics Loss = 235.850098
# Epoch 2200/3000, Total Loss = 235.744888, Data Loss = 232.880707, Physics Loss = 235.744888
# Epoch 2400/3000, Total Loss = 235.636795, Data Loss = 232.779205, Physics Loss = 235.636795
# Epoch 2600/3000, Total Loss = 235.520294, Data Loss = 232.669540, Physics Loss = 235.520294
# Epoch 2800/3000, Total Loss = 235.367218, Data Loss = 232.525665, Physics Loss = 235.367218
# Epoch 3000/3000, Total Loss = 235.265015, Data Loss = 232.431717, Physics Loss = 235.265015
#
# --- Evaluation | LAG = 30, lambda_data = 0.0, lambda_phys = 1.0 ---
# Mean Squared Error (MSE):   163.6515
# Mean Absolute Error (MAE):  10.2176
# Root Mean Squared Error (RMSE): 12.7926
# Normalized Mean Squared Error (NMSE): 1.0404
#
# >>> Training MLP+Physics | LAG = 30, lambda_data = 0.3, lambda_phys = 0.7
#
# --- First 10 Samples: True vs Physics AQI (Targeted Day) ---
# Sample 01: True=19.000, Physics=19.444, Diff=0.444
# Sample 02: True=24.500, Physics=24.583, Diff=0.083
# Sample 03: True=21.000, Physics=20.556, Diff=0.444
# Sample 04: True=6.000, Physics=6.111, Diff=0.111
# Sample 05: True=41.333, Physics=41.667, Diff=0.333
# Sample 06: True=64.000, Physics=64.548, Diff=0.548
# Sample 07: True=32.000, Physics=31.667, Diff=0.333
# Sample 08: True=42.333, Physics=43.704, Diff=1.370
# Sample 09: True=25.500, Physics=25.556, Diff=0.056
# Sample 10: True=50.000, Physics=51.648, Diff=1.648
# Epoch 1: Data Loss = 2360.555176, Physics Loss = 2389.119629, Total Loss = 2380.550293
# Epoch 2: Data Loss = 2357.660400, Physics Loss = 2386.207031, Total Loss = 2377.643066
# Epoch 3: Data Loss = 2354.862793, Physics Loss = 2383.392578, Total Loss = 2374.833496
# Epoch 4: Data Loss = 2352.145752, Physics Loss = 2380.658691, Total Loss = 2372.104736
# Epoch 5: Data Loss = 2349.502197, Physics Loss = 2377.999512, Total Loss = 2369.450195
# Epoch 200/3000, Total Loss = 593.097290, Data Loss = 586.380066, Physics Loss = 595.976135
# Epoch 400/3000, Total Loss = 256.777405, Data Loss = 254.198608, Physics Loss = 257.882629
# Epoch 600/3000, Total Loss = 236.253662, Data Loss = 234.156189, Physics Loss = 237.152573
# Epoch 800/3000, Total Loss = 235.857483, Data Loss = 233.787277, Physics Loss = 236.744705
# Epoch 1000/3000, Total Loss = 235.594666, Data Loss = 233.532028, Physics Loss = 236.478668
# Epoch 1200/3000, Total Loss = 235.459198, Data Loss = 233.401550, Physics Loss = 236.341034
# Epoch 1400/3000, Total Loss = 235.353394, Data Loss = 233.300232, Physics Loss = 236.233307
# Epoch 1600/3000, Total Loss = 235.240646, Data Loss = 233.192123, Physics Loss = 236.118576
# Epoch 1800/3000, Total Loss = 235.098785, Data Loss = 233.053253, Physics Loss = 235.975433
# Epoch 2000/3000, Total Loss = 234.986633, Data Loss = 232.944916, Physics Loss = 235.861649
# Epoch 2200/3000, Total Loss = 234.884674, Data Loss = 232.844315, Physics Loss = 235.759109
# Epoch 2400/3000, Total Loss = 234.781250, Data Loss = 232.746506, Physics Loss = 235.653305
# Epoch 2600/3000, Total Loss = 234.633972, Data Loss = 232.605698, Physics Loss = 235.503235
# Epoch 2800/3000, Total Loss = 234.514130, Data Loss = 232.489700, Physics Loss = 235.381744
# Epoch 3000/3000, Total Loss = 234.413177, Data Loss = 232.396576, Physics Loss = 235.277435
#
# --- Evaluation | LAG = 30, lambda_data = 0.3, lambda_phys = 0.7 ---
# Mean Squared Error (MSE):   163.8552
# Mean Absolute Error (MAE):  10.2260
# Root Mean Squared Error (RMSE): 12.8006
# Normalized Mean Squared Error (NMSE): 1.0417
#
# >>> Training MLP+Physics | LAG = 30, lambda_data = 0.5, lambda_phys = 0.5
#
# --- First 10 Samples: True vs Physics AQI (Targeted Day) ---
# Sample 01: True=19.000, Physics=19.444, Diff=0.444
# Sample 02: True=24.500, Physics=24.583, Diff=0.083
# Sample 03: True=21.000, Physics=20.556, Diff=0.444
# Sample 04: True=6.000, Physics=6.111, Diff=0.111
# Sample 05: True=41.333, Physics=41.667, Diff=0.333
# Sample 06: True=64.000, Physics=64.548, Diff=0.548
# Sample 07: True=32.000, Physics=31.667, Diff=0.333
# Sample 08: True=42.333, Physics=43.704, Diff=1.370
# Sample 09: True=25.500, Physics=25.556, Diff=0.056
# Sample 10: True=50.000, Physics=51.648, Diff=1.648
# Epoch 1: Data Loss = 2360.555176, Physics Loss = 2389.119629, Total Loss = 2374.837402
# Epoch 2: Data Loss = 2357.660400, Physics Loss = 2386.207031, Total Loss = 2371.933594
# Epoch 3: Data Loss = 2354.862793, Physics Loss = 2383.392578, Total Loss = 2369.127686
# Epoch 4: Data Loss = 2352.145752, Physics Loss = 2380.658691, Total Loss = 2366.402344
# Epoch 5: Data Loss = 2349.502197, Physics Loss = 2377.999512, Total Loss = 2363.750977
# Epoch 200/3000, Total Loss = 591.381592, Data Loss = 586.576904, Physics Loss = 596.186340
# Epoch 400/3000, Total Loss = 256.063141, Data Loss = 254.206772, Physics Loss = 257.919525
# Epoch 600/3000, Total Loss = 235.657196, Data Loss = 234.143219, Physics Loss = 237.171158
# Epoch 800/3000, Total Loss = 235.264832, Data Loss = 233.770477, Physics Loss = 236.759186
# Epoch 1000/3000, Total Loss = 235.004608, Data Loss = 233.515732, Physics Loss = 236.493500
# Epoch 1200/3000, Total Loss = 234.870270, Data Loss = 233.385269, Physics Loss = 236.355255
# Epoch 1400/3000, Total Loss = 234.766815, Data Loss = 233.284836, Physics Loss = 236.248810
# Epoch 1600/3000, Total Loss = 234.656342, Data Loss = 233.177094, Physics Loss = 236.135590
# Epoch 1800/3000, Total Loss = 234.514130, Data Loss = 233.037155, Physics Loss = 235.991089
# Epoch 2000/3000, Total Loss = 234.401764, Data Loss = 232.927750, Physics Loss = 235.875793
# Epoch 2200/3000, Total Loss = 234.300171, Data Loss = 232.828003, Physics Loss = 235.772324
# Epoch 2400/3000, Total Loss = 234.194977, Data Loss = 232.725555, Physics Loss = 235.664413
# Epoch 2600/3000, Total Loss = 234.046021, Data Loss = 232.581284, Physics Loss = 235.510773
# Epoch 2800/3000, Total Loss = 233.934021, Data Loss = 232.472015, Physics Loss = 235.396011
# Epoch 3000/3000, Total Loss = 233.834076, Data Loss = 232.376434, Physics Loss = 235.291718
#
# --- Evaluation | LAG = 30, lambda_data = 0.5, lambda_phys = 0.5 ---
# Mean Squared Error (MSE):   164.0469
# Mean Absolute Error (MAE):  10.2332
# Root Mean Squared Error (RMSE): 12.8081
# Normalized Mean Squared Error (NMSE): 1.0429
#
# >>> Training MLP+Physics | LAG = 30, lambda_data = 0.7, lambda_phys = 0.3
#
# --- First 10 Samples: True vs Physics AQI (Targeted Day) ---
# Sample 01: True=19.000, Physics=19.444, Diff=0.444
# Sample 02: True=24.500, Physics=24.583, Diff=0.083
# Sample 03: True=21.000, Physics=20.556, Diff=0.444
# Sample 04: True=6.000, Physics=6.111, Diff=0.111
# Sample 05: True=41.333, Physics=41.667, Diff=0.333
# Sample 06: True=64.000, Physics=64.548, Diff=0.548
# Sample 07: True=32.000, Physics=31.667, Diff=0.333
# Sample 08: True=42.333, Physics=43.704, Diff=1.370
# Sample 09: True=25.500, Physics=25.556, Diff=0.056
# Sample 10: True=50.000, Physics=51.648, Diff=1.648
# Epoch 1: Data Loss = 2360.555176, Physics Loss = 2389.119629, Total Loss = 2369.124512
# Epoch 2: Data Loss = 2357.660400, Physics Loss = 2386.207031, Total Loss = 2366.224365
# Epoch 3: Data Loss = 2354.862793, Physics Loss = 2383.392578, Total Loss = 2363.421875
# Epoch 4: Data Loss = 2352.145752, Physics Loss = 2380.658691, Total Loss = 2360.699707
# Epoch 5: Data Loss = 2349.502197, Physics Loss = 2377.999512, Total Loss = 2358.051270
# Epoch 200/3000, Total Loss = 589.659485, Data Loss = 586.772644, Physics Loss = 596.395508
# Epoch 400/3000, Total Loss = 255.310974, Data Loss = 254.188583, Physics Loss = 257.929901
# Epoch 600/3000, Total Loss = 235.056458, Data Loss = 234.137558, Physics Loss = 237.200577
# Epoch 800/3000, Total Loss = 234.667084, Data Loss = 233.761139, Physics Loss = 236.780960
# Epoch 1000/3000, Total Loss = 234.410156, Data Loss = 233.507492, Physics Loss = 236.516357
# Epoch 1200/3000, Total Loss = 234.275726, Data Loss = 233.375366, Physics Loss = 236.376617
# Epoch 1400/3000, Total Loss = 234.174072, Data Loss = 233.275299, Physics Loss = 236.271225
# Epoch 1600/3000, Total Loss = 234.068909, Data Loss = 233.171753, Physics Loss = 236.162277
# Epoch 1800/3000, Total Loss = 233.927856, Data Loss = 233.032761, Physics Loss = 236.016464
# Epoch 2000/3000, Total Loss = 233.813873, Data Loss = 232.919464, Physics Loss = 235.900803
# Epoch 2200/3000, Total Loss = 233.712982, Data Loss = 232.820328, Physics Loss = 235.795822
# Epoch 2400/3000, Total Loss = 233.598526, Data Loss = 232.707275, Physics Loss = 235.678101
# Epoch 2600/3000, Total Loss = 233.461365, Data Loss = 232.571991, Physics Loss = 235.536575
# Epoch 2800/3000, Total Loss = 233.353363, Data Loss = 232.465759, Physics Loss = 235.424469
# Epoch 3000/3000, Total Loss = 233.254425, Data Loss = 232.370758, Physics Loss = 235.316299
#
# --- Evaluation | LAG = 30, lambda_data = 0.7, lambda_phys = 0.3 ---
# Mean Squared Error (MSE):   164.2064
# Mean Absolute Error (MAE):  10.2399
# Root Mean Squared Error (RMSE): 12.8143
# Normalized Mean Squared Error (NMSE): 1.0439
#
# >>> Training MLP+Physics | LAG = 30, lambda_data = 1.0, lambda_phys = 0.0
#
# --- First 10 Samples: True vs Physics AQI (Targeted Day) ---
# Sample 01: True=19.000, Physics=19.444, Diff=0.444
# Sample 02: True=24.500, Physics=24.583, Diff=0.083
# Sample 03: True=21.000, Physics=20.556, Diff=0.444
# Sample 04: True=6.000, Physics=6.111, Diff=0.111
# Sample 05: True=41.333, Physics=41.667, Diff=0.333
# Sample 06: True=64.000, Physics=64.548, Diff=0.548
# Sample 07: True=32.000, Physics=31.667, Diff=0.333
# Sample 08: True=42.333, Physics=43.704, Diff=1.370
# Sample 09: True=25.500, Physics=25.556, Diff=0.056
# Sample 10: True=50.000, Physics=51.648, Diff=1.648
# Epoch 1: Data Loss = 2360.555176, Physics Loss = 2389.119629, Total Loss = 2360.555176
# Epoch 2: Data Loss = 2357.660400, Physics Loss = 2386.207031, Total Loss = 2357.660400
# Epoch 3: Data Loss = 2354.862793, Physics Loss = 2383.392578, Total Loss = 2354.862793
# Epoch 4: Data Loss = 2352.145752, Physics Loss = 2380.658691, Total Loss = 2352.145752
# Epoch 5: Data Loss = 2349.502197, Physics Loss = 2377.999512, Total Loss = 2349.502197
# Epoch 200/3000, Total Loss = 587.075806, Data Loss = 587.075806, Physics Loss = 596.718872
# Epoch 400/3000, Total Loss = 254.221924, Data Loss = 254.221924, Physics Loss = 258.006287
# Epoch 600/3000, Total Loss = 234.139542, Data Loss = 234.139542, Physics Loss = 237.250977
# Epoch 800/3000, Total Loss = 233.757233, Data Loss = 233.757233, Physics Loss = 236.823227
# Epoch 1000/3000, Total Loss = 233.506714, Data Loss = 233.506714, Physics Loss = 236.562485
# Epoch 1200/3000, Total Loss = 233.370834, Data Loss = 233.370834, Physics Loss = 236.419220
# Epoch 1400/3000, Total Loss = 233.267395, Data Loss = 233.267395, Physics Loss = 236.309402
# Epoch 1600/3000, Total Loss = 233.152130, Data Loss = 233.152130, Physics Loss = 236.189148
# Epoch 1800/3000, Total Loss = 233.009415, Data Loss = 233.009415, Physics Loss = 236.041214
# Epoch 2000/3000, Total Loss = 232.899933, Data Loss = 232.899933, Physics Loss = 235.928574
# Epoch 2200/3000, Total Loss = 232.803955, Data Loss = 232.803955, Physics Loss = 235.828720
# Epoch 2400/3000, Total Loss = 232.675369, Data Loss = 232.675369, Physics Loss = 235.693253
# Epoch 2600/3000, Total Loss = 232.553955, Data Loss = 232.553955, Physics Loss = 235.567673
# Epoch 2800/3000, Total Loss = 232.446686, Data Loss = 232.446686, Physics Loss = 235.449783
# Epoch 3000/3000, Total Loss = 232.349426, Data Loss = 232.349426, Physics Loss = 235.343445
#
# --- Evaluation | LAG = 30, lambda_data = 1.0, lambda_phys = 0.0 ---
# Mean Squared Error (MSE):   164.6068
# Mean Absolute Error (MAE):  10.2548
# Root Mean Squared Error (RMSE): 12.8299
# Normalized Mean Squared Error (NMSE): 1.0464
#
# ===== Final MLP+Physics Lambda Sweep Results =====
#     LAG        Model  lambda_data  lambda_phys        MAE       RMSE      NMSE
# 0     1  MLP+Physics          0.0          1.0   8.169524  10.634921  0.655978
# 1     1  MLP+Physics          0.3          0.7   8.182556  10.639510  0.656544
# 2     1  MLP+Physics          0.5          0.5   8.191781  10.643046  0.656980
# 3     1  MLP+Physics          0.7          0.3   8.201737  10.647720  0.657557
# 4     1  MLP+Physics          1.0          0.0   8.214918  10.653516  0.658274
# 5     7  MLP+Physics          0.0          1.0  10.178263  13.137431  1.022817
# 6     7  MLP+Physics          0.3          0.7  10.193355  13.150793  1.024898
# 7     7  MLP+Physics          0.5          0.5  10.201481  13.159128  1.026198
# 8     7  MLP+Physics          0.7          0.3  10.215176  13.172466  1.028279
# 9     7  MLP+Physics          1.0          0.0  10.228941  13.186716  1.030505
# 10   14  MLP+Physics          0.0          1.0  10.092488  12.680373  1.022784
# 11   14  MLP+Physics          0.3          0.7  10.109174  12.693669  1.024930
# 12   14  MLP+Physics          0.5          0.5  10.064912  12.639571  1.016213
# 13   14  MLP+Physics          0.7          0.3  10.071305  12.644450  1.016997
# 14   14  MLP+Physics          1.0          0.0  10.083861  12.653777  1.018498
# 15   30  MLP+Physics          0.0          1.0  10.217638  12.792633  1.040364
# 16   30  MLP+Physics          0.3          0.7  10.225971  12.800595  1.041659
# 17   30  MLP+Physics          0.5          0.5  10.233247  12.808081  1.042878
# 18   30  MLP+Physics          0.7          0.3  10.239927  12.814305  1.043892
# 19   30  MLP+Physics          1.0          0.0  10.254799  12.829917  1.046437
